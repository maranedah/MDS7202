# %% [markdown]
# # Clase 8: Reorganización, Multi-Índices y Agregación de Datos
#
# **MDS7202: Laboratorio de Programación Científica para Ciencia de Datos**
#
# **Profesor: Matías Rojas**

# %% [markdown]
# ## Objetivos
#
#
# Es Habitual que la información se encuentre dispersa en distintas fuentes y con distintas formas.
# El dar forma, organizar, unir y agrupar estas distintas fuentes de información es una componente muy importante del análisis de datos.
#
# - Aprender a organizar los `DataFrames`: transponer, pivotear y fundir (melt).
# - Explorar el mecanismo de agrupación de pandas: Group By, aggregate, transform y filter.
#
# ### Roadmap
#
# **Unidad 3: Manejo de Datos con Pandas y AED**
#
# - [X] Introducción a Manejo de Datos Tabulares con Pandas
# - [ ] Reorganización, Multi-Índices y Agregación de Datos.
# - [ ] Concatenación y Combinación de Múltiples Fuentes de Datos.
# - [ ] Trabajo con strings y datos temporales, categóricos y ordinales en Pandas.

# %% [markdown]
# ## Cargando Índices para una Vida Mejor
#
# En esta clase, seguiremos usando los datos de índices para una Vida Mejor de la OECD:
#
#
# <img src="https://i.ibb.co/hC1RRsS/oecd.png" alt="OECD Better life index"/>
#
#
# http://www.oecdbetterlifeindex.org/
#
# https://stats.oecd.org/index.aspx?DataSetCode=BLI
#
# Son 11 temas considerados como esenciales para el bienestar de la población. Cada crierio contiene uno o mas indicadores:

# %% [markdown]
# | Tema | Indicador (Inglés) | Indicador (Español) | Unidad | Descripción |
# |---|---|---|---|---|
# | Vivienda 🏠 | Dwellings without basic facilities | Vivienda con Instalaciones Básicas | Porcentaje | Porcentaje de personas con inodoros de agua corriente dentro del hogar, año disponible más reciente |
# |  | Housing expenditure | Gastos en Vivienda | Porcentaje | Proporción de costos de vivienda en el ingreso neto ajustado de las familias, año disponible más reciente |
# |  | Rooms per person | Habitaciones por Persona | Ratio | Número promedio de habitaciones compartidas por persona en una vivienda, año disponible más reciente |
# | Ingresos 💰 | Household net adjusted disposable income | Ingreso Familiar Disponible | US Dollar | Cantidad promedio de dinero que una familia gana al año, después de impuestos, año disponible más reciente |
# |  | Household net wealth | Patrimonio Neto Familiar | US Dollar | Valor total promedio de los activos financieros de una familia (ahorros, acciones) menos sus pasivos (créditos), año disponible más reciente |
# | Empleo ⚙️ | Labour market insecurity | Seguridad en el Empleo | Porcentaje | Pérdida esperada de ingresos cuando alguien queda desempleado, año disponible más reciente |
# |  | Employment rate | Tasa de Empleo | Porcentaje | Porcentaje de personas, de 15 a 64 años de edad, actualmente con empleo remunerado, año disponible más reciente |
# |  | Long-term unemployment rate | Tasa de Empleo a Largo Plazo | Porcentaje | Porcentaje de personas, de 15 a 64 años de edad, que no trabajan pero que han buscado empleo activamente durante más de un año, año disponible más reciente |
# |  | Personal earnings | Ingresos Personales | US Dollar | Ingresos anuales promedio por empleado de tiempo completo, año disponible más reciente |
# | Comunidad 🧑‍🤝‍🧑   | Quality of support network  | Calidad del Apoyo Social | Porcentaje | Porcentaje de personas con amigos o parientes en quienes confiar en caso de necesidad |
# | Educación 📚 | Educational attainment | Nivel de Educación | Porcentaje | Porcentaje de personas, de 25 a 64 años de edad, graduadas por lo menos de educación media superior, año disponible más reciente |
# |  | Student skills | Competencias de estudiantes en matemáticas, lectura y ciencias | Puntaje promedio | Desempeño promedio de estudiantes de 15 años de edad, según PISA (Programa para la Evaluación Internacional de Estudiantes) |
# |  | Years in education  | Nivel de educación | Años | Duración promedio de la educación formal en la que un niño de cinco años de edad puede esperar matricularse durante su vida |
# | Medio Ambiente 🌳 | Air pollution | Contaminación del Aire | Microgramos por metro cúbico | Concentración promedio de partículas (PM2.5) en ciudades con poblaciones mayores de 100,000 personas, medida en microgramos por metro cúbico, año disponible más reciente |
# |  | Water quality | Calidad del Agua | Porcentaje | Porcentaje de personas que informan estar satisfechas con la calidad del agua local |
# | Compromiso Cívico 🗳️  | Stakeholder engagement for developing regulations | Participación de los interesados en la elaboración de regulaciones | Puntaje promedio | Nivel de transparencia gubernamental al preparar las regulaciones, año disponible más reciente |
# |  | Voter turnout | Participación electoral | Porcentaje | Porcentaje de votantes registrados que votaron durante las elecciones recientes, año disponible más reciente |
# | Salud ⚕️ | Life expectancy | Esperanza de vida | Años | Número promedio de años que una persona puede esperar vivir, año disponible más reciente |
# |  | Self-reported health | Salud según informan las personas | Porcentaje | Porcentaje de personas que informan que su salud es «buena o muy buena», año disponible más reciente |
# | Satisfacción ✨ | Life satisfaction | Satisfacción ante la vida | Puntaje promedio | Autoevaluación promedio de satisfacción ante la vida, en una escala de 0 a 10 |
# | Seguridad 🌃 | Feeling safe walking alone at night | Sentimiento de seguridad al caminar solos por la noche | Porcentaje | Porcentaje de personas que reportan sentirse seguras al caminar solas por la noche  |
# |  | Homicide rate | Tasa de homicidios | Ratio | Número promedio de homicidios reportados por 100,000 personas, año disponible más reciente |
# | Balance Vida Trabajo 🧘 | Employees working very long hours | Empleados que trabajan muchas horas | Porcentaje | Porcentaje de empleados que trabajan más de cincuenta horas a la semana en promedio, año disponible más reciente |
# |  | Time devoted to leisure and personal care | Tiempo destinado al ocio y el cuidado personal | Horas | Número promedio de minutos al día dedicados al ocio y el cuidado personal, incluidos el sueño y la alimentación |

# %%
import pandas as pd

dataset = pd.read_csv("https://raw.githubusercontent.com/maranedah/MDS7202/main/clases/Clase%207%20-%20Scipy%20%2B%20Pandas/resources/dataset.csv")
dataset.head(3)
# Out:
#      Country  Air pollution  Dwellings without basic facilities  \
# 0  Australia            5.0                                 NaN
# 1    Austria           16.0                                 0.9
# 2    Belgium           15.0                                 1.9
#
#    Educational attainment  Employees working very long hours  Employment rate  \
# 0                    81.0                          12.840000        73.000000
# 1                    85.0                           6.590000        72.000000
# 2                    77.0                           4.703333        63.333333
#
#    Feeling safe walking alone at night  Homicide rate  \
# 0                            64.133333       1.100000
# 1                            80.700000       0.466667
# 2                            70.266667       1.033333
#
#    Household net adjusted disposable income  Household net wealth  ...  \
# 0                                   32759.0              427064.0  ...
# 1                                   33541.0              308325.0  ...
# 2                                   30364.0              386006.0  ...
#
#    Quality of support network  Rooms per person  Self-reported health  \
# 0                       95.25               NaN                 87.25
# 1                       92.00               1.6                 70.60
# 2                       92.00               2.2                 73.60
#
#    Stakeholder engagement for developing regulations  Student skills  \
# 0                                                2.7           411.2
# 1                                                1.3           492.8
# 2                                                2.0           503.8
#
#    Time devoted to leisure and personal care  Voter turnout  Water quality  \
# 0                                  14.350000           91.0      92.666667
# 1                                  14.530000           80.0      92.000000
# 2                                  15.663333           89.0      83.666667
#
#    Years in education  GPD per capita (2018)
# 0           20.966667            57395.91947
# 1           17.000000            51525.04643
# 2           19.300000            47491.32326
#
# [3 rows x 26 columns]

# %%
dataset.shape
# Out:
# (41, 26)

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=41, step=1)

# %% [markdown]
# ---
#
# ## 1.- Transponer Datos
#
# Simplemente invertir las filas por las columnas.

# %%
dataset.head()
# Out:
#      Country  Air pollution  Dwellings without basic facilities  \
# 0  Australia            5.0                                 NaN
# 1    Austria           16.0                                 0.9
# 2    Belgium           15.0                                 1.9
# 3     Brazil           10.0                                 6.7
# 4     Canada            7.0                                 0.2
#
#    Educational attainment  Employees working very long hours  Employment rate  \
# 0               81.000000                          12.840000        73.000000
# 1               85.000000                           6.590000        72.000000
# 2               77.000000                           4.703333        63.333333
# 3               49.000000                           7.006667        61.000000
# 4               91.333333                           3.673333        73.333333
#
#    Feeling safe walking alone at night  Homicide rate  \
# 0                            64.133333       1.100000
# 1                            80.700000       0.466667
# 2                            70.266667       1.033333
# 3                            35.866667      27.000000
# 4                            82.500000       1.266667
#
#    Household net adjusted disposable income  Household net wealth  ...  \
# 0                                   32759.0              427064.0  ...
# 1                                   33541.0              308325.0  ...
# 2                                   30364.0              386006.0  ...
# 3                                       NaN                   NaN  ...
# 4                                   30854.0              423849.0  ...
#
#    Quality of support network  Rooms per person  Self-reported health  \
# 0                       95.25               NaN                 87.25
# 1                       92.00               1.6                 70.60
# 2                       92.00               2.2                 73.60
# 3                       89.25               NaN                   NaN
# 4                       93.25               2.6                 87.80
#
#    Stakeholder engagement for developing regulations  Student skills  \
# 0                                                2.7           411.2
# 1                                                1.3           492.8
# 2                                                2.0           503.8
# 3                                                2.2           398.2
# 4                                                2.9           523.2
#
#    Time devoted to leisure and personal care  Voter turnout  Water quality  \
# 0                                  14.350000           91.0      92.666667
# 1                                  14.530000           80.0      92.000000
# 2                                  15.663333           89.0      83.666667
# 3                                        NaN           79.0      73.000000
# 4                                  14.553333           68.0      91.000000
#
#    Years in education  GPD per capita (2018)
# 0           20.966667           57395.919470
# 1           17.000000           51525.046430
# 2           19.300000           47491.323260
# 3           16.166667            9001.234249
# 4           17.333333           46313.171370
#
# [5 rows x 26 columns]

# %%
dataset.T
# Out:
#                                                             0            1   \
# Country                                              Australia      Austria
# Air pollution                                              5.0         16.0
# Dwellings without basic facilities                         NaN          0.9
# Educational attainment                                    81.0         85.0
# Employees working very long hours                        12.84         6.59
# Employment rate                                           73.0         72.0
# Feeling safe walking alone at night                  64.133333         80.7
# Homicide rate                                              1.1     0.466667
# Household net adjusted disposable income               32759.0      33541.0
# Household net wealth                                  427064.0     308325.0
# Housing expenditure                                       20.0         21.0
# Labour market insecurity                                 5.922        4.076
# Life expectancy                                           82.5         81.7
# Life satisfaction                                         7.35        7.225
# Long-term unemployment rate                           1.306667         1.83
# Personal earnings                                      49126.0      50349.0
# Quality of support network                               95.25         92.0
# Rooms per person                                           NaN          1.6
# Self-reported health                                     87.25         70.6
# Stakeholder engagement for developing regulations          2.7          1.3
# Student skills                                           411.2        492.8
# Time devoted to leisure and personal care                14.35        14.53
# Voter turnout                                             91.0         80.0
# Water quality                                        92.666667         92.0
# Years in education                                   20.966667         17.0
# GPD per capita (2018)                              57395.91947  51525.04643
#
#                                                             2            3   \
# Country                                                Belgium       Brazil
# Air pollution                                             15.0         10.0
# Dwellings without basic facilities                         1.9          6.7
# Educational attainment                                    77.0         49.0
# Employees working very long hours                     4.703333     7.006667
# Employment rate                                      63.333333         61.0
# Feeling safe walking alone at night                  70.266667    35.866667
# Homicide rate                                         1.033333         27.0
# Household net adjusted disposable income               30364.0          NaN
# Household net wealth                                  386006.0          NaN
# Housing expenditure                                       21.0          NaN
# Labour market insecurity                                 4.052          NaN
# Life expectancy                                           81.5    74.766667
# Life satisfaction                                          7.0          6.4
# Long-term unemployment rate                           3.533333          NaN
# Personal earnings                                      49675.0          NaN
# Quality of support network                                92.0        89.25
# Rooms per person                                           2.2          NaN
# Self-reported health                                      73.6          NaN
# Stakeholder engagement for developing regulations          2.0          2.2
# Student skills                                           503.8        398.2
# Time devoted to leisure and personal care            15.663333          NaN
# Voter turnout                                             89.0         79.0
# Water quality                                        83.666667         73.0
# Years in education                                        19.3    16.166667
# GPD per capita (2018)                              47491.32326  9001.234249
#
#                                                             4            5   \
# Country                                                 Canada        Chile
# Air pollution                                              7.0         16.0
# Dwellings without basic facilities                         0.2          9.4
# Educational attainment                               91.333333         65.0
# Employees working very long hours                     3.673333     9.316667
# Employment rate                                      73.333333    62.666667
# Feeling safe walking alone at night                       82.5         48.0
# Homicide rate                                         1.266667          4.2
# Household net adjusted disposable income               30854.0          NaN
# Household net wealth                                  423849.0     100967.0
# Housing expenditure                                       22.0         18.0
# Labour market insecurity                                 7.048        8.168
# Life expectancy                                      81.866667         79.9
# Life satisfaction                                        7.425         6.48
# Long-term unemployment rate                           0.763333          NaN
# Personal earnings                                      47622.0      25879.0
# Quality of support network                               93.25         84.6
# Rooms per person                                           2.6          1.2
# Self-reported health                                      87.8         57.0
# Stakeholder engagement for developing regulations          2.9          1.3
# Student skills                                           523.2        443.8
# Time devoted to leisure and personal care            14.553333          NaN
# Voter turnout                                             68.0         47.0
# Water quality                                             91.0         71.0
# Years in education                                   17.333333         17.5
# GPD per capita (2018)                              46313.17137  15924.79424
#
#                                                             6   \
# Country                                               Colombia
# Air pollution                                             10.0
# Dwellings without basic facilities                        23.9
# Educational attainment                                    54.0
# Employees working very long hours                    26.006667
# Employment rate                                           67.0
# Feeling safe walking alone at night                  44.566667
# Homicide rate                                             25.0
# Household net adjusted disposable income                   NaN
# Household net wealth                                       NaN
# Housing expenditure                                       17.0
# Labour market insecurity                                   NaN
# Life expectancy                                      76.233333
# Life satisfaction                                     6.266667
# Long-term unemployment rate                               0.82
# Personal earnings                                          NaN
# Quality of support network                                89.0
# Rooms per person                                           1.2
# Self-reported health                                       NaN
# Stakeholder engagement for developing regulations          1.4
# Student skills                                           412.8
# Time devoted to leisure and personal care                  NaN
# Voter turnout                                             53.0
# Water quality                                        74.666667
# Years in education                                        14.1
# GPD per capita (2018)                              6718.585324
#
#                                                                7   \
# Country                                            Czech Republic
# Air pollution                                                20.0
# Dwellings without basic facilities                            0.7
# Educational attainment                                  93.666667
# Employees working very long hours                        5.496667
# Employment rate                                         73.666667
# Feeling safe walking alone at night                     72.533333
# Homicide rate                                                 0.5
# Household net adjusted disposable income                  21453.0
# Household net wealth                                          NaN
# Housing expenditure                                          24.0
# Labour market insecurity                                    7.208
# Life expectancy                                              79.1
# Life satisfaction                                             6.7
# Long-term unemployment rate                              1.056667
# Personal earnings                                         25372.0
# Quality of support network                                  91.75
# Rooms per person                                              1.4
# Self-reported health                                         60.8
# Stakeholder engagement for developing regulations             1.6
# Student skills                                              492.2
# Time devoted to leisure and personal care                     NaN
# Voter turnout                                                61.0
# Water quality                                           86.666667
# Years in education                                           17.9
# GPD per capita (2018)                                 23046.94913
#
#                                                             8            9   \
# Country                                                Denmark      Estonia
# Air pollution                                              9.0          8.0
# Dwellings without basic facilities                         0.5          7.0
# Educational attainment                                    81.0    88.666667
# Employees working very long hours                     2.316667     2.436667
# Employment rate                                           74.0         74.0
# Feeling safe walking alone at night                  83.566667    69.633333
# Homicide rate                                              0.6     3.166667
# Household net adjusted disposable income               29606.0      19697.0
# Household net wealth                                  118637.0     159373.0
# Housing expenditure                                       23.0         17.0
# Labour market insecurity                                 4.606        4.392
# Life expectancy                                           80.9    77.766667
# Life satisfaction                                         7.65         5.78
# Long-term unemployment rate                           1.313333     1.916667
# Personal earnings                                      51466.0      24336.0
# Quality of support network                                95.5         91.2
# Rooms per person                                           1.9          1.6
# Self-reported health                                      72.6         54.4
# Stakeholder engagement for developing regulations          2.0          2.7
# Student skills                                           505.2        525.8
# Time devoted to leisure and personal care            15.873333    14.886667
# Voter turnout                                             86.0         64.0
# Water quality                                             95.0         84.0
# Years in education                                        19.5         17.7
# GPD per capita (2018)                              61390.69301  23258.46758
#
#                                                    ...           31  \
# Country                                            ...       Russia
# Air pollution                                      ...         15.0
# Dwellings without basic facilities                 ...         14.8
# Educational attainment                             ...         94.0
# Employees working very long hours                  ...         0.14
# Employment rate                                    ...    70.333333
# Feeling safe walking alone at night                ...    53.466667
# Homicide rate                                      ...     9.933333
# Household net adjusted disposable income           ...          NaN
# Household net wealth                               ...          NaN
# Housing expenditure                                ...         18.0
# Labour market insecurity                           ...          NaN
# Life expectancy                                    ...         71.8
# Life satisfaction                                  ...         5.88
# Long-term unemployment rate                        ...     1.586667
# Personal earnings                                  ...          NaN
# Quality of support network                         ...         90.0
# Rooms per person                                   ...          0.9
# Self-reported health                               ...    43.333333
# Stakeholder engagement for developing regulations  ...          NaN
# Student skills                                     ...        491.8
# Time devoted to leisure and personal care          ...          NaN
# Voter turnout                                      ...         68.0
# Water quality                                      ...    55.333333
# Years in education                                 ...         16.2
# GPD per capita (2018)                              ...  11584.99538
#
#                                                                 32  \
# Country                                            Slovak Republic
# Air pollution                                                 21.0
# Dwellings without basic facilities                             1.2
# Educational attainment                                   91.333333
# Employees working very long hours                         4.073333
# Employment rate                                               66.0
# Feeling safe walking alone at night                           63.7
# Homicide rate                                                  0.8
# Household net adjusted disposable income                   20474.0
# Household net wealth                                      119696.0
# Housing expenditure                                           23.0
# Labour market insecurity                                    21.376
# Life expectancy                                          77.266667
# Life satisfaction                                            6.425
# Long-term unemployment rate                               4.773333
# Personal earnings                                          24328.0
# Quality of support network                                    91.5
# Rooms per person                                               1.1
# Self-reported health                                          68.6
# Stakeholder engagement for developing regulations              3.0
# Student skills                                               463.4
# Time devoted to leisure and personal care                      NaN
# Voter turnout                                                 60.0
# Water quality                                            84.666667
# Years in education                                       15.766667
# GPD per capita (2018)                                  19428.11621
#
#                                                            33            34  \
# Country                                              Slovenia  South Africa
# Air pollution                                            16.0          22.0
# Dwellings without basic facilities                        0.4          37.0
# Educational attainment                                   88.0     73.333333
# Employees working very long hours                    4.333333         17.84
# Employment rate                                     69.333333     43.333333
# Feeling safe walking alone at night                 86.166667     36.333333
# Homicide rate                                             0.6          14.0
# Household net adjusted disposable income              20820.0           NaN
# Household net wealth                                 203044.0           NaN
# Housing expenditure                                      18.0          18.0
# Labour market insecurity                                6.338           NaN
# Life expectancy                                     81.266667          57.5
# Life satisfaction                                    5.933333           4.7
# Long-term unemployment rate                          3.176667     16.643333
# Personal earnings                                     34933.0           NaN
# Quality of support network                          91.666667          88.0
# Rooms per person                                          1.5           NaN
# Self-reported health                                     64.4           NaN
# Stakeholder engagement for developing regulations         2.5           NaN
# Student skills                                          510.4           NaN
# Time devoted to leisure and personal care               14.73         14.77
# Voter turnout                                            53.0          73.0
# Water quality                                       89.666667          67.0
# Years in education                                  18.366667           NaN
# GPD per capita (2018)                              26054.5421   6374.028196
#
#                                                             35           36  \
# Country                                                  Spain       Sweden
# Air pollution                                             11.0          6.0
# Dwellings without basic facilities                         0.1          0.0
# Educational attainment                                    59.0         83.0
# Employees working very long hours                     3.963333     1.066667
# Employment rate                                      62.333333    76.666667
# Feeling safe walking alone at night                  82.166667    75.566667
# Homicide rate                                              0.6          0.9
# Household net adjusted disposable income               23999.0      31287.0
# Household net wealth                                  373548.0          NaN
# Housing expenditure                                       21.0         19.0
# Labour market insecurity                                23.792        4.232
# Life expectancy                                           83.4    82.366667
# Life satisfaction                                        6.225          7.4
# Long-term unemployment rate                               7.71     1.113333
# Personal earnings                                      38507.0      42393.0
# Quality of support network                               92.75         91.5
# Rooms per person                                           1.9          1.7
# Self-reported health                                      74.0         75.0
# Stakeholder engagement for developing regulations          1.8          2.0
# Student skills                                           492.4        497.0
# Time devoted to leisure and personal care                15.86    15.176667
# Voter turnout                                             70.0         86.0
# Water quality                                        72.333333         96.0
# Years in education                                        17.9         19.3
# GPD per capita (2018)                              30337.67913  54589.06039
#
#                                                             37           38  \
# Country                                            Switzerland       Turkey
# Air pollution                                             15.0         20.0
# Dwellings without basic facilities                         0.1          8.0
# Educational attainment                               87.666667         39.0
# Employees working very long hours                         0.37    31.043333
# Employment rate                                      79.666667    51.666667
# Feeling safe walking alone at night                  85.333333    59.833333
# Homicide rate                                              0.6     1.366667
# Household net adjusted disposable income               37466.0          NaN
# Household net wealth                                       NaN          NaN
# Housing expenditure                                       22.0         20.0
# Labour market insecurity                                   NaN        12.06
# Life expectancy                                      83.666667         78.0
# Life satisfaction                                          7.5         5.52
# Long-term unemployment rate                           1.826667         2.66
# Personal earnings                                      62283.0          NaN
# Quality of support network                           93.333333         86.0
# Rooms per person                                           1.9          1.0
# Self-reported health                                      77.4         70.4
# Stakeholder engagement for developing regulations          2.3          1.5
# Student skills                                           507.4        426.8
# Time devoted to leisure and personal care                  NaN    14.653333
# Voter turnout                                             49.0         86.0
# Water quality                                        95.333333         65.0
# Years in education                                        17.5         18.3
# GPD per capita (2018)                              82818.10816  9370.176355
#
#                                                                39  \
# Country                                            United Kingdom
# Air pollution                                                11.0
# Dwellings without basic facilities                            0.3
# Educational attainment                                       81.0
# Employees working very long hours                       12.123333
# Employment rate                                              75.0
# Feeling safe walking alone at night                     77.766667
# Homicide rate                                            0.166667
# Household net adjusted disposable income                  28715.0
# Household net wealth                                     548392.0
# Housing expenditure                                          26.0
# Labour market insecurity                                    4.744
# Life expectancy                                              81.2
# Life satisfaction                                            6.86
# Long-term unemployment rate                              1.126667
# Personal earnings                                         43732.0
# Quality of support network                                   94.0
# Rooms per person                                              1.9
# Self-reported health                                         70.0
# Stakeholder engagement for developing regulations             3.1
# Student skills                                              502.4
# Time devoted to leisure and personal care               14.916667
# Voter turnout                                                69.0
# Water quality                                           83.666667
# Years in education                                           17.5
# GPD per capita (2018)                                 43043.22782
#
#                                                               40
# Country                                            United States
# Air pollution                                               10.0
# Dwellings without basic facilities                           0.1
# Educational attainment                                 90.666667
# Employees working very long hours                          10.99
# Employment rate                                             70.0
# Feeling safe walking alone at night                         73.9
# Homicide rate                                                5.5
# Household net adjusted disposable income                 45284.0
# Household net wealth                                    632100.0
# Housing expenditure                                         19.0
# Labour market insecurity                                   9.072
# Life expectancy                                             78.6
# Life satisfaction                                            7.0
# Long-term unemployment rate                             0.656667
# Personal earnings                                        60558.0
# Quality of support network                                 91.75
# Rooms per person                                             2.4
# Self-reported health                                        86.8
# Stakeholder engagement for developing regulations            3.1
# Student skills                                             489.4
# Time devoted to leisure and personal care                  14.44
# Voter turnout                                               65.0
# Water quality                                          82.666667
# Years in education                                          17.2
# GPD per capita (2018)                                62996.66482
#
# [26 rows x 41 columns]

# %%
dataset.loc[0,:]
# Out:
# Country                                                Australia
# Air pollution                                                5.0
# Dwellings without basic facilities                           NaN
# Educational attainment                                      81.0
# Employees working very long hours                          12.84
# Employment rate                                             73.0
# Feeling safe walking alone at night                    64.133333
# Homicide rate                                                1.1
# Household net adjusted disposable income                 32759.0
# Household net wealth                                    427064.0
# Housing expenditure                                         20.0
# Labour market insecurity                                   5.922
# Life expectancy                                             82.5
# Life satisfaction                                           7.35
# Long-term unemployment rate                             1.306667
# Personal earnings                                        49126.0
# Quality of support network                                 95.25
# Rooms per person                                             NaN
# Self-reported health                                       87.25
# Stakeholder engagement for developing regulations            2.7
# Student skills                                             411.2
# Time devoted to leisure and personal care                  14.35
# Voter turnout                                               91.0
# Water quality                                          92.666667
# Years in education                                     20.966667
# GPD per capita (2018)                                57395.91947
# Name: 0, dtype: object

# %%
dataset.T.loc['Country',:]
# Out:
# 0           Australia
# 1             Austria
# 2             Belgium
# 3              Brazil
# 4              Canada
# 5               Chile
# 6            Colombia
# 7      Czech Republic
# 8             Denmark
# 9             Estonia
# 10            Finland
# 11             France
# 12            Germany
# 13             Greece
# 14            Hungary
# 15            Iceland
# 16            Ireland
# 17             Israel
# 18              Italy
# 19              Japan
# 20              Korea
# 21             Latvia
# 22          Lithuania
# 23         Luxembourg
# 24             Mexico
# 25        Netherlands
# 26        New Zealand
# 27             Norway
# 28       OECD - Total
# 29             Poland
# 30           Portugal
# 31             Russia
# 32    Slovak Republic
# 33           Slovenia
# 34       South Africa
# 35              Spain
# 36             Sweden
# 37        Switzerland
# 38             Turkey
# 39     United Kingdom
# 40      United States
# Name: Country, dtype: object

# %%
dataset.T.T
# Out:
#             Country Air pollution Dwellings without basic facilities  \
# 0         Australia           5.0                                NaN
# 1           Austria          16.0                                0.9
# 2           Belgium          15.0                                1.9
# 3            Brazil          10.0                                6.7
# 4            Canada           7.0                                0.2
# 5             Chile          16.0                                9.4
# 6          Colombia          10.0                               23.9
# 7    Czech Republic          20.0                                0.7
# 8           Denmark           9.0                                0.5
# 9           Estonia           8.0                                7.0
# 10          Finland           6.0                                0.5
# 11           France          13.0                                0.5
# 12          Germany          14.0                                0.2
# 13           Greece          18.0                                0.5
# 14          Hungary          19.0                                4.7
# 15          Iceland           3.0                                0.0
# 16          Ireland           7.0                                1.0
# 17           Israel          21.0                                NaN
# 18            Italy          18.0                                0.7
# 19            Japan          14.0                                6.4
# 20            Korea          28.0                                2.5
# 21           Latvia          11.0                               13.9
# 22        Lithuania          14.0                               13.6
# 23       Luxembourg          12.0                                0.5
# 24           Mexico          16.0                               25.5
# 25      Netherlands          14.0                                0.1
# 26      New Zealand           5.0                                NaN
# 27           Norway           5.0                                0.0
# 28     OECD - Total          14.0                                4.4
# 29           Poland          22.0                                3.0
# 30         Portugal          10.0                                1.0
# 31           Russia          15.0                               14.8
# 32  Slovak Republic          21.0                                1.2
# 33         Slovenia          16.0                                0.4
# 34     South Africa          22.0                               37.0
# 35            Spain          11.0                                0.1
# 36           Sweden           6.0                                0.0
# 37      Switzerland          15.0                                0.1
# 38           Turkey          20.0                                8.0
# 39   United Kingdom          11.0                                0.3
# 40    United States          10.0                                0.1
#
#    Educational attainment Employees working very long hours Employment rate  \
# 0                    81.0                             12.84            73.0
# 1                    85.0                              6.59            72.0
# 2                    77.0                          4.703333       63.333333
# 3                    49.0                          7.006667            61.0
# 4               91.333333                          3.673333       73.333333
# 5                    65.0                          9.316667       62.666667
# 6                    54.0                         26.006667            67.0
# 7               93.666667                          5.496667       73.666667
# 8                    81.0                          2.316667            74.0
# 9               88.666667                          2.436667            74.0
# 10                   88.0                          3.816667       70.333333
# 11              78.333333                          7.656667       65.333333
# 12              86.666667                          4.196667       75.333333
# 13                   73.0                              6.28       53.333333
# 14                   84.0                          2.976667            68.0
# 15                   77.0                         14.866667       85.666667
# 16                   82.0                              5.26       67.333333
# 17              87.333333                         15.273333            69.0
# 18                   61.0                          4.003333            58.0
# 19                    NaN                               NaN            75.0
# 20              87.666667                               NaN       66.666667
# 21              87.666667                              1.28            70.0
# 22              92.666667                          0.546667       70.333333
# 23              76.666667                              3.74       66.333333
# 24              37.666667                             27.28       61.666667
# 25              78.333333                          0.413333       75.666667
# 26              78.666667                         15.036667            77.0
# 27                   82.0                          2.886667            74.0
# 28              78.333333                         10.786667            68.0
# 29                   92.0                          5.823333            66.0
# 30              47.666667                              8.34            68.0
# 31                   94.0                              0.14       70.333333
# 32              91.333333                          4.073333            66.0
# 33                   88.0                          4.333333       69.333333
# 34              73.333333                             17.84       43.333333
# 35                   59.0                          3.963333       62.333333
# 36                   83.0                          1.066667       76.666667
# 37              87.666667                              0.37       79.666667
# 38                   39.0                         31.043333       51.666667
# 39                   81.0                         12.123333            75.0
# 40              90.666667                             10.99            70.0
#
#    Feeling safe walking alone at night Homicide rate  \
# 0                            64.133333           1.1
# 1                                 80.7      0.466667
# 2                            70.266667      1.033333
# 3                            35.866667          27.0
# 4                                 82.5      1.266667
# 5                                 48.0           4.2
# 6                            44.566667          25.0
# 7                            72.533333           0.5
# 8                            83.566667           0.6
# 9                            69.633333      3.166667
# 10                           85.266667      1.266667
# 11                                70.7      0.466667
# 12                                72.6           0.5
# 13                                60.2      0.833333
# 14                                56.7           1.0
# 15                                86.3           0.5
# 16                                76.0      0.666667
# 17                           69.966667      1.833333
# 18                                58.6           0.6
# 19                                72.8           0.2
# 20                           66.666667           1.0
# 21                           63.066667      4.933333
# 22                           56.233333      3.433333
# 23                           75.866667      0.566667
# 24                           41.966667     18.633333
# 25                           82.066667           0.6
# 26                           66.266667           1.3
# 27                           90.033333           0.4
# 28                                68.5      3.733333
# 29                           67.466667      0.733333
# 30                           73.766667           1.0
# 31                           53.466667      9.933333
# 32                                63.7           0.8
# 33                           86.166667           0.6
# 34                           36.333333          14.0
# 35                           82.166667           0.6
# 36                           75.566667           0.9
# 37                           85.333333           0.6
# 38                           59.833333      1.366667
# 39                           77.766667      0.166667
# 40                                73.9           5.5
#
#    Household net adjusted disposable income Household net wealth  ...  \
# 0                                   32759.0             427064.0  ...
# 1                                   33541.0             308325.0  ...
# 2                                   30364.0             386006.0  ...
# 3                                       NaN                  NaN  ...
# 4                                   30854.0             423849.0  ...
# 5                                       NaN             100967.0  ...
# 6                                       NaN                  NaN  ...
# 7                                   21453.0                  NaN  ...
# 8                                   29606.0             118637.0  ...
# 9                                   19697.0             159373.0  ...
# 10                                  29943.0             200827.0  ...
# 11                                  31304.0             280653.0  ...
# 12                                  34294.0             259667.0  ...
# 13                                  17700.0             150134.0  ...
# 14                                      NaN             104458.0  ...
# 15                                      NaN                  NaN  ...
# 16                                  25310.0             217130.0  ...
# 17                                      NaN                  NaN  ...
# 18                                  26588.0             279889.0  ...
# 19                                  29798.0             305878.0  ...
# 20                                  21882.0             285980.0  ...
# 21                                  16275.0              70160.0  ...
# 22                                  21660.0                  NaN  ...
# 23                                  39264.0             769053.0  ...
# 24                                      NaN                  NaN  ...
# 25                                  29333.0             157824.0  ...
# 26                                      NaN             388514.0  ...
# 27                                  35725.0             228936.0  ...
# 28                                  33604.0             408376.0  ...
# 29                                  19814.0             210991.0  ...
# 30                                  21203.0             232666.0  ...
# 31                                      NaN                  NaN  ...
# 32                                  20474.0             119696.0  ...
# 33                                  20820.0             203044.0  ...
# 34                                      NaN                  NaN  ...
# 35                                  23999.0             373548.0  ...
# 36                                  31287.0                  NaN  ...
# 37                                  37466.0                  NaN  ...
# 38                                      NaN                  NaN  ...
# 39                                  28715.0             548392.0  ...
# 40                                  45284.0             632100.0  ...
#
#    Quality of support network Rooms per person Self-reported health  \
# 0                       95.25              NaN                87.25
# 1                        92.0              1.6                 70.6
# 2                        92.0              2.2                 73.6
# 3                       89.25              NaN                  NaN
# 4                       93.25              2.6                 87.8
# 5                        84.6              1.2                 57.0
# 6                        89.0              1.2                  NaN
# 7                       91.75              1.4                 60.8
# 8                        95.5              1.9                 72.6
# 9                        91.2              1.6                 54.4
# 10                       94.8              1.9                 70.2
# 11                       89.0              1.8                 66.4
# 12                       90.5              1.8                 65.4
# 13                       78.8              1.2                 76.0
# 14                       85.5              1.2                 61.0
# 15                       98.0              1.6                 76.0
# 16                       95.0              2.1                 82.8
# 17                       88.5              1.2                86.75
# 18                       91.8              1.4                 71.8
# 19                      88.75              1.9                 34.8
# 20                  78.333333              1.5                 33.0
# 21                       86.2              1.2                 48.0
# 22                       88.4              1.5                 45.6
# 23                       93.0              1.9                 69.4
# 24                       81.6              1.0            65.666667
# 25                       91.0              1.9                 75.8
# 26                      96.25              2.4                89.25
# 27                       94.0              2.1                 77.2
# 28                       88.4              1.8                 69.2
# 29                       86.0              1.1                 60.0
# 30                       88.0              1.7                 48.2
# 31                       90.0              0.9            43.333333
# 32                       91.5              1.1                 68.6
# 33                  91.666667              1.5                 64.4
# 34                       88.0              NaN                  NaN
# 35                      92.75              1.9                 74.0
# 36                       91.5              1.7                 75.0
# 37                  93.333333              1.9                 77.4
# 38                       86.0              1.0                 70.4
# 39                       94.0              1.9                 70.0
# 40                      91.75              2.4                 86.8
#
#    Stakeholder engagement for developing regulations Student skills  \
# 0                                                2.7          411.2
# 1                                                1.3          492.8
# 2                                                2.0          503.8
# 3                                                2.2          398.2
# 4                                                2.9          523.2
# 5                                                1.3          443.8
# 6                                                1.4          412.8
# 7                                                1.6          492.2
# 8                                                2.0          505.2
# 9                                                2.7          525.8
# 10                                               2.2          523.6
# 11                                               2.1          497.4
# 12                                               1.8          511.0
# 13                                               1.8          460.2
# 14                                               1.2          475.0
# 15                                               2.1          480.8
# 16                                               1.3          509.8
# 17                                               2.5          470.0
# 18                                               2.5          485.0
# 19                                               1.4          528.8
# 20                                               2.9          520.0
# 21                                               2.2          487.6
# 22                                               2.4          476.6
# 23                                               1.7          485.4
# 24                                               3.2          416.0
# 25                                               2.6          509.6
# 26                                               2.5          506.2
# 27                                               2.2          504.8
# 28                                               2.4          490.4
# 29                                               2.6          505.4
# 30                                               1.5          499.4
# 31                                               NaN          491.8
# 32                                               3.0          463.4
# 33                                               2.5          510.4
# 34                                               NaN            NaN
# 35                                               1.8          492.4
# 36                                               2.0          497.0
# 37                                               2.3          507.4
# 38                                               1.5          426.8
# 39                                               3.1          502.4
# 40                                               3.1          489.4
#
#    Time devoted to leisure and personal care Voter turnout Water quality  \
# 0                                      14.35          91.0     92.666667
# 1                                      14.53          80.0          92.0
# 2                                  15.663333          89.0     83.666667
# 3                                        NaN          79.0          73.0
# 4                                  14.553333          68.0          91.0
# 5                                        NaN          47.0          71.0
# 6                                        NaN          53.0     74.666667
# 7                                        NaN          61.0     86.666667
# 8                                  15.873333          86.0          95.0
# 9                                  14.886667          64.0          84.0
# 10                                 15.163333          67.0          95.0
# 11                                 16.336667          75.0          81.0
# 12                                 15.613333          76.0     91.333333
# 13                                       NaN          64.0     69.333333
# 14                                       NaN          70.0          77.0
# 15                                       NaN          79.0     98.666667
# 16                                       NaN          65.0          85.0
# 17                                       NaN          72.0          67.0
# 18                                 16.313333          73.0          71.0
# 19                                       NaN          53.0          87.0
# 20                                 14.583333          77.0          76.0
# 21                                 13.826667          59.0     79.333333
# 22                                       NaN          51.0     80.666667
# 23                                       NaN          91.0          84.0
# 24                                       NaN          63.0     67.666667
# 25                                       NaN          82.0          93.0
# 26                                 14.883333          80.0          89.0
# 27                                 15.563333          78.0     97.666667
# 28                                 14.896667          68.0          81.0
# 29                                     14.39          55.0          82.0
# 30                                       NaN          56.0     86.333333
# 31                                       NaN          68.0     55.333333
# 32                                       NaN          60.0     84.666667
# 33                                     14.73          53.0     89.666667
# 34                                     14.77          73.0          67.0
# 35                                     15.86          70.0     72.333333
# 36                                 15.176667          86.0          96.0
# 37                                       NaN          49.0     95.333333
# 38                                 14.653333          86.0          65.0
# 39                                 14.916667          69.0     83.666667
# 40                                     14.44          65.0     82.666667
#
#    Years in education GPD per capita (2018)
# 0           20.966667           57395.91947
# 1                17.0           51525.04643
# 2                19.3           47491.32326
# 3           16.166667           9001.234249
# 4           17.333333           46313.17137
# 5                17.5           15924.79424
# 6                14.1           6718.585324
# 7                17.9           23046.94913
# 8                19.5           61390.69301
# 9                17.7           23258.46758
# 10          19.833333           50021.29106
# 11               16.5           41631.09074
# 12               18.1           47639.00344
# 13               19.0           20324.30501
# 14          16.433333           16150.77276
# 15          19.033333           72968.70423
# 16               18.1           78621.22796
# 17          15.633333           41719.72544
# 18               16.6           34520.08516
# 19          16.366667           39159.42356
# 20          17.266667           33340.26515
# 21          18.033333           17805.28031
# 22               18.4           19080.61737
# 23               15.1           116654.2611
# 24          15.166667           9673.443674
# 25          18.666667           53048.09621
# 26               17.7           42949.93058
# 27          18.333333           81734.46557
# 28               17.2           39299.24225
# 29          17.666667           15460.64428
# 30          16.933333           23461.57186
# 31               16.2           11584.99538
# 32          15.766667           19428.11621
# 33          18.366667            26054.5421
# 34                NaN           6374.028196
# 35               17.9           30337.67913
# 36               19.3           54589.06039
# 37               17.5           82818.10816
# 38               18.3           9370.176355
# 39               17.5           43043.22782
# 40               17.2           62996.66482
#
# [41 rows x 26 columns]

# %%
len(dataset)
# Out:
# 41

# %% [markdown]
# ---
#
# ## 2.- Pivotear Datos
#
#
# El dataset que usamos la clase pasada está relativamente ordenado.

# %%
dataset

# %%
dataset.shape

# %%
dataset.head(5)

# %%
len(dataset['Country'].unique())

# %%
len(dataset)

# %% [markdown]
# Sin embargo, originalmente tenía la siguiente estructura:

# %%
dataset_original = pd.read_csv("https://raw.githubusercontent.com/maranedah/MDS7202/main/clases/Clase%208%20-%20Pandas%20-%20Parte%20II/resources/bli_original.csv", keep_default_na=False)
dataset_original
# Out:
#      Continent         Country INDICATOR                          Indicator  \
# 0           OC       Australia   JE_LMIS           Labour market insecurity
# 1           EU         Austria   JE_LMIS           Labour market insecurity
# 2           EU         Belgium   JE_LMIS           Labour market insecurity
# 3           NA          Canada   JE_LMIS           Labour market insecurity
# 4           EU  Czech Republic   JE_LMIS           Labour market insecurity
# ...        ...             ...       ...                                ...
# 2364        EU       Lithuania   WL_EWLH  Employees working very long hours
# 2365        SA        Colombia   WL_EWLH  Employees working very long hours
# 2366        EU       Lithuania   WL_EWLH  Employees working very long hours
# 2367        SA        Colombia   WL_EWLH  Employees working very long hours
# 2368        EU       Lithuania   WL_EWLH  Employees working very long hours
#
#      MEASURE Measure INEQUALITY Inequality Unit Code        Unit  \
# 0          L   Value        TOT      Total        PC  Percentage
# 1          L   Value        TOT      Total        PC  Percentage
# 2          L   Value        TOT      Total        PC  Percentage
# 3          L   Value        TOT      Total        PC  Percentage
# 4          L   Value        TOT      Total        PC  Percentage
# ...      ...     ...        ...        ...       ...         ...
# 2364       L   Value        TOT      Total        PC  Percentage
# 2365       L   Value         MN        Men        PC  Percentage
# 2366       L   Value         MN        Men        PC  Percentage
# 2367       L   Value        WMN      Women        PC  Percentage
# 2368       L   Value        WMN      Women        PC  Percentage
#
#       PowerCode Code PowerCode Reference Period Code Reference Period  Value  \
# 0                  0     Units                                          5.40
# 1                  0     Units                                          3.50
# 2                  0     Units                                          3.70
# 3                  0     Units                                          6.00
# 4                  0     Units                                          3.10
# ...              ...       ...                   ...              ...    ...
# 2364               0     Units                                          0.54
# 2365               0     Units                                         32.09
# 2366               0     Units                                          0.67
# 2367               0     Units                                         19.37
# 2368               0     Units                                          0.43
#
#      Flag Codes Flags
# 0
# 1
# 2
# 3
# 4
# ...         ...   ...
# 2364
# 2365
# 2366
# 2367
# 2368
#
# [2369 rows x 17 columns]

# %%
dataset_original.loc[:, ["Continent", "Country", "Indicator", "Unit", "Value"]].head(20)
# Out:
#    Continent         Country                 Indicator        Unit  Value
# 0         OC       Australia  Labour market insecurity  Percentage    5.4
# 1         EU         Austria  Labour market insecurity  Percentage    3.5
# 2         EU         Belgium  Labour market insecurity  Percentage    3.7
# 3         NA          Canada  Labour market insecurity  Percentage    6.0
# 4         EU  Czech Republic  Labour market insecurity  Percentage    3.1
# 5         EU         Denmark  Labour market insecurity  Percentage    4.2
# 6         EU         Finland  Labour market insecurity  Percentage    3.9
# 7         EU          France  Labour market insecurity  Percentage    7.6
# 8         EU         Germany  Labour market insecurity  Percentage    2.7
# 9         EU          Greece  Labour market insecurity  Percentage   29.8
# 10        EU         Hungary  Labour market insecurity  Percentage    4.7
# 11        EU         Iceland  Labour market insecurity  Percentage    0.7
# 12        EU         Ireland  Labour market insecurity  Percentage    7.8
# 13        EU           Italy  Labour market insecurity  Percentage   12.3
# 14        AS           Japan  Labour market insecurity  Percentage    1.4
# 15        AS           Korea  Labour market insecurity  Percentage    2.6
# 16        EU      Luxembourg  Labour market insecurity  Percentage    1.7
# 17        NA          Mexico  Labour market insecurity  Percentage    5.5
# 18        EU     Netherlands  Labour market insecurity  Percentage    4.8
# 19        OC     New Zealand  Labour market insecurity  Percentage    4.7

# %%
dataset_original.shape

# %% [markdown]
# Cada fila de este dataset contiene información acerca de los paises y de los indicadores y el valor del indicador. Esta forma es conocida como **long**.
#
# **Pivotear**
#
# Para convertirla al formato con el que hemos estado trabajando, **wide**, debemos pivotear la tabla:

# %%
dataset.head(3)

# %% [markdown]
# ![Pivot](https://i.ibb.co/Qd82x89/pivot.png)

# %%
dataset_original["Indicator"].unique()

# %%
dataset_original.head().loc[:, ["Country", "Indicator", "Value"]]
# Out:
#           Country                 Indicator  Value
# 0       Australia  Labour market insecurity    5.4
# 1         Austria  Labour market insecurity    3.5
# 2         Belgium  Labour market insecurity    3.7
# 3          Canada  Labour market insecurity    6.0
# 4  Czech Republic  Labour market insecurity    3.1

# %% [markdown]
# > **Ejercicio ✏️**: Pivotear la tabla original de los datos de la OECD

# %%
indice = "Country"
columna = "Indicator"
valor = "Value"

# %%
df = pd.pivot_table(dataset_original, index=indice, columns=columna, values=valor).head(5)

# %%
df.head()
# Out:
# Indicator  Air pollution  Dwellings without basic facilities  \
# Country
# Australia            5.0                                 NaN
# Austria             16.0                                 0.9
# Belgium             15.0                                 1.9
# Brazil              10.0                                 6.7
# Canada               7.0                                 0.2
#
# Indicator  Educational attainment  Employees working very long hours  \
# Country
# Australia               81.000000                          12.840000
# Austria                 85.000000                           6.590000
# Belgium                 77.000000                           4.703333
# Brazil                  49.000000                           7.006667
# Canada                  91.333333                           3.673333
#
# Indicator  Employment rate  Feeling safe walking alone at night  \
# Country
# Australia        73.000000                            64.133333
# Austria          72.000000                            80.700000
# Belgium          63.333333                            70.266667
# Brazil           61.000000                            35.866667
# Canada           73.333333                            82.500000
#
# Indicator  Homicide rate  Household net adjusted disposable income  \
# Country
# Australia       1.100000                                   32759.0
# Austria         0.466667                                   33541.0
# Belgium         1.033333                                   30364.0
# Brazil         27.000000                                       NaN
# Canada          1.266667                                   30854.0
#
# Indicator  Household net wealth  Housing expenditure  ...  Personal earnings  \
# Country                                               ...
# Australia              427064.0                 20.0  ...            49126.0
# Austria                308325.0                 21.0  ...            50349.0
# Belgium                386006.0                 21.0  ...            49675.0
# Brazil                      NaN                  NaN  ...                NaN
# Canada                 423849.0                 22.0  ...            47622.0
#
# Indicator  Quality of support network  Rooms per person  Self-reported health  \
# Country
# Australia                       95.25               NaN                 87.25
# Austria                         92.00               1.6                 70.60
# Belgium                         92.00               2.2                 73.60
# Brazil                          89.25               NaN                   NaN
# Canada                          93.25               2.6                 87.80
#
# Indicator  Stakeholder engagement for developing regulations  Student skills  \
# Country
# Australia                                                2.7           411.2
# Austria                                                  1.3           492.8
# Belgium                                                  2.0           503.8
# Brazil                                                   2.2           398.2
# Canada                                                   2.9           523.2
#
# Indicator  Time devoted to leisure and personal care  Voter turnout  \
# Country
# Australia                                  14.350000           91.0
# Austria                                    14.530000           80.0
# Belgium                                    15.663333           89.0
# Brazil                                           NaN           79.0
# Canada                                     14.553333           68.0
#
# Indicator  Water quality  Years in education
# Country
# Australia      92.666667           20.966667
# Austria        92.000000           17.000000
# Belgium        83.666667           19.300000
# Brazil         73.000000           16.166667
# Canada         91.000000           17.333333
#
# [5 rows x 24 columns]

# %% [markdown]
# ---
#
# ## 3.- Multi-Índices
#
# Hasta el mmomento solo hemos trabajado con `Dataframes` que contienen solo un nivel de filas o columnas. Sin embargo, es posible también agregar más niveles a los indices y a las columnas.
# Esto se le conoce como multi-índice.

# %%
dataset_original.loc[:, ["Continent", "Country", "Indicator", "Unit", "Value"]].head()

# %% [markdown]
# Para agregar niveles de columnas, en el proceso de pivoteo vamos a indicar que tanto `Unit` como `Indicator` sean niveles de las columnas; y que a la vez, tanto `Continent` como `Country` sean indices para las filas.
#
# El resultado de esto puede ser visto en el siguiente `DataFrame`:

# %%
dataset_multindex = pd.pivot_table(
    dataset_original,
    index=["Continent", "Country"],
    columns=["Unit", "Indicator"],
    values="Value",
)

dataset_multindex
# Out:
# Unit                          Average score  \
# Indicator                 Life satisfaction
# Continent Country
# AF        South Africa             4.700000
# AS        Israel                   7.225000
#           Japan                    5.900000
#           Korea                    5.866667
# EU        Austria                  7.225000
#           Belgium                  7.000000
#           Czech Republic           6.700000
#           Denmark                  7.650000
#           Estonia                  5.780000
#           Finland                  7.660000
#           France                   6.540000
#           Germany                  7.100000
#           Greece                   5.340000
#           Hungary                  5.680000
#           Iceland                  7.580000
#           Ireland                  7.050000
#           Italy                    6.140000
#           Latvia                   5.940000
#           Lithuania                5.980000
#           Luxembourg               6.900000
#           Netherlands              7.500000
#           Norway                   7.620000
#           Poland                   6.100000
#           Portugal                 5.480000
#           Russia                   5.880000
#           Slovak Republic          6.425000
#           Slovenia                 5.933333
#           Spain                    6.225000
#           Sweden                   7.400000
#           Switzerland              7.500000
#           Turkey                   5.520000
#           United Kingdom           6.860000
# NA        Canada                   7.425000
#           Mexico                   6.466667
#           United States            7.000000
# OC        Australia                7.350000
#           New Zealand              7.300000
# OECD      OECD - Total             6.480000
# SA        Brazil                   6.400000
#           Chile                    6.480000
#           Colombia                 6.266667
#
# Unit                                                                         \
# Indicator                 Stakeholder engagement for developing regulations
# Continent Country
# AF        South Africa                                                  NaN
# AS        Israel                                                        2.5
#           Japan                                                         1.4
#           Korea                                                         2.9
# EU        Austria                                                       1.3
#           Belgium                                                       2.0
#           Czech Republic                                                1.6
#           Denmark                                                       2.0
#           Estonia                                                       2.7
#           Finland                                                       2.2
#           France                                                        2.1
#           Germany                                                       1.8
#           Greece                                                        1.8
#           Hungary                                                       1.2
#           Iceland                                                       2.1
#           Ireland                                                       1.3
#           Italy                                                         2.5
#           Latvia                                                        2.2
#           Lithuania                                                     2.4
#           Luxembourg                                                    1.7
#           Netherlands                                                   2.6
#           Norway                                                        2.2
#           Poland                                                        2.6
#           Portugal                                                      1.5
#           Russia                                                        NaN
#           Slovak Republic                                               3.0
#           Slovenia                                                      2.5
#           Spain                                                         1.8
#           Sweden                                                        2.0
#           Switzerland                                                   2.3
#           Turkey                                                        1.5
#           United Kingdom                                                3.1
# NA        Canada                                                        2.9
#           Mexico                                                        3.2
#           United States                                                 3.1
# OC        Australia                                                     2.7
#           New Zealand                                                   2.5
# OECD      OECD - Total                                                  2.4
# SA        Brazil                                                        2.2
#           Chile                                                         1.3
#           Colombia                                                      1.4
#
# Unit                                      \
# Indicator                 Student skills
# Continent Country
# AF        South Africa               NaN
# AS        Israel                   470.0
#           Japan                    528.8
#           Korea                    520.0
# EU        Austria                  492.8
#           Belgium                  503.8
#           Czech Republic           492.2
#           Denmark                  505.2
#           Estonia                  525.8
#           Finland                  523.6
#           France                   497.4
#           Germany                  511.0
#           Greece                   460.2
#           Hungary                  475.0
#           Iceland                  480.8
#           Ireland                  509.8
#           Italy                    485.0
#           Latvia                   487.6
#           Lithuania                476.6
#           Luxembourg               485.4
#           Netherlands              509.6
#           Norway                   504.8
#           Poland                   505.4
#           Portugal                 499.4
#           Russia                   491.8
#           Slovak Republic          463.4
#           Slovenia                 510.4
#           Spain                    492.4
#           Sweden                   497.0
#           Switzerland              507.4
#           Turkey                   426.8
#           United Kingdom           502.4
# NA        Canada                   523.2
#           Mexico                   416.0
#           United States            489.4
# OC        Australia                411.2
#           New Zealand              506.2
# OECD      OECD - Total             490.4
# SA        Brazil                   398.2
#           Chile                    443.8
#           Colombia                 412.8
#
# Unit                                                          Hours  \
# Indicator                 Time devoted to leisure and personal care
# Continent Country
# AF        South Africa                                    14.770000
# AS        Israel                                                NaN
#           Japan                                                 NaN
#           Korea                                           14.583333
# EU        Austria                                         14.530000
#           Belgium                                         15.663333
#           Czech Republic                                        NaN
#           Denmark                                         15.873333
#           Estonia                                         14.886667
#           Finland                                         15.163333
#           France                                          16.336667
#           Germany                                         15.613333
#           Greece                                                NaN
#           Hungary                                               NaN
#           Iceland                                               NaN
#           Ireland                                               NaN
#           Italy                                           16.313333
#           Latvia                                          13.826667
#           Lithuania                                             NaN
#           Luxembourg                                            NaN
#           Netherlands                                           NaN
#           Norway                                          15.563333
#           Poland                                          14.390000
#           Portugal                                              NaN
#           Russia                                                NaN
#           Slovak Republic                                       NaN
#           Slovenia                                        14.730000
#           Spain                                           15.860000
#           Sweden                                          15.176667
#           Switzerland                                           NaN
#           Turkey                                          14.653333
#           United Kingdom                                  14.916667
# NA        Canada                                          14.553333
#           Mexico                                                NaN
#           United States                                   14.440000
# OC        Australia                                       14.350000
#           New Zealand                                     14.883333
# OECD      OECD - Total                                    14.896667
# SA        Brazil                                                NaN
#           Chile                                                 NaN
#           Colombia                                              NaN
#
# Unit                      Micrograms per cubic metre  \
# Indicator                              Air pollution
# Continent Country
# AF        South Africa                          22.0
# AS        Israel                                21.0
#           Japan                                 14.0
#           Korea                                 28.0
# EU        Austria                               16.0
#           Belgium                               15.0
#           Czech Republic                        20.0
#           Denmark                                9.0
#           Estonia                                8.0
#           Finland                                6.0
#           France                                13.0
#           Germany                               14.0
#           Greece                                18.0
#           Hungary                               19.0
#           Iceland                                3.0
#           Ireland                                7.0
#           Italy                                 18.0
#           Latvia                                11.0
#           Lithuania                             14.0
#           Luxembourg                            12.0
#           Netherlands                           14.0
#           Norway                                 5.0
#           Poland                                22.0
#           Portugal                              10.0
#           Russia                                15.0
#           Slovak Republic                       21.0
#           Slovenia                              16.0
#           Spain                                 11.0
#           Sweden                                 6.0
#           Switzerland                           15.0
#           Turkey                                20.0
#           United Kingdom                        11.0
# NA        Canada                                 7.0
#           Mexico                                16.0
#           United States                         10.0
# OC        Australia                              5.0
#           New Zealand                            5.0
# OECD      OECD - Total                          14.0
# SA        Brazil                                10.0
#           Chile                                 16.0
#           Colombia                              10.0
#
# Unit                                              Percentage  \
# Indicator                 Dwellings without basic facilities
# Continent Country
# AF        South Africa                                  37.0
# AS        Israel                                         NaN
#           Japan                                          6.4
#           Korea                                          2.5
# EU        Austria                                        0.9
#           Belgium                                        1.9
#           Czech Republic                                 0.7
#           Denmark                                        0.5
#           Estonia                                        7.0
#           Finland                                        0.5
#           France                                         0.5
#           Germany                                        0.2
#           Greece                                         0.5
#           Hungary                                        4.7
#           Iceland                                        0.0
#           Ireland                                        1.0
#           Italy                                          0.7
#           Latvia                                        13.9
#           Lithuania                                     13.6
#           Luxembourg                                     0.5
#           Netherlands                                    0.1
#           Norway                                         0.0
#           Poland                                         3.0
#           Portugal                                       1.0
#           Russia                                        14.8
#           Slovak Republic                                1.2
#           Slovenia                                       0.4
#           Spain                                          0.1
#           Sweden                                         0.0
#           Switzerland                                    0.1
#           Turkey                                         8.0
#           United Kingdom                                 0.3
# NA        Canada                                         0.2
#           Mexico                                        25.5
#           United States                                  0.1
# OC        Australia                                      NaN
#           New Zealand                                    NaN
# OECD      OECD - Total                                   4.4
# SA        Brazil                                         6.7
#           Chile                                          9.4
#           Colombia                                      23.9
#
# Unit                                              \
# Indicator                 Educational attainment
# Continent Country
# AF        South Africa                 73.333333
# AS        Israel                       87.333333
#           Japan                              NaN
#           Korea                        87.666667
# EU        Austria                      85.000000
#           Belgium                      77.000000
#           Czech Republic               93.666667
#           Denmark                      81.000000
#           Estonia                      88.666667
#           Finland                      88.000000
#           France                       78.333333
#           Germany                      86.666667
#           Greece                       73.000000
#           Hungary                      84.000000
#           Iceland                      77.000000
#           Ireland                      82.000000
#           Italy                        61.000000
#           Latvia                       87.666667
#           Lithuania                    92.666667
#           Luxembourg                   76.666667
#           Netherlands                  78.333333
#           Norway                       82.000000
#           Poland                       92.000000
#           Portugal                     47.666667
#           Russia                       94.000000
#           Slovak Republic              91.333333
#           Slovenia                     88.000000
#           Spain                        59.000000
#           Sweden                       83.000000
#           Switzerland                  87.666667
#           Turkey                       39.000000
#           United Kingdom               81.000000
# NA        Canada                       91.333333
#           Mexico                       37.666667
#           United States                90.666667
# OC        Australia                    81.000000
#           New Zealand                  78.666667
# OECD      OECD - Total                 78.333333
# SA        Brazil                       49.000000
#           Chile                        65.000000
#           Colombia                     54.000000
#
# Unit                                                                         \
# Indicator                 Employees working very long hours Employment rate
# Continent Country
# AF        South Africa                            17.840000       43.333333
# AS        Israel                                  15.273333       69.000000
#           Japan                                         NaN       75.000000
#           Korea                                         NaN       66.666667
# EU        Austria                                  6.590000       72.000000
#           Belgium                                  4.703333       63.333333
#           Czech Republic                           5.496667       73.666667
#           Denmark                                  2.316667       74.000000
#           Estonia                                  2.436667       74.000000
#           Finland                                  3.816667       70.333333
#           France                                   7.656667       65.333333
#           Germany                                  4.196667       75.333333
#           Greece                                   6.280000       53.333333
#           Hungary                                  2.976667       68.000000
#           Iceland                                 14.866667       85.666667
#           Ireland                                  5.260000       67.333333
#           Italy                                    4.003333       58.000000
#           Latvia                                   1.280000       70.000000
#           Lithuania                                0.546667       70.333333
#           Luxembourg                               3.740000       66.333333
#           Netherlands                              0.413333       75.666667
#           Norway                                   2.886667       74.000000
#           Poland                                   5.823333       66.000000
#           Portugal                                 8.340000       68.000000
#           Russia                                   0.140000       70.333333
#           Slovak Republic                          4.073333       66.000000
#           Slovenia                                 4.333333       69.333333
#           Spain                                    3.963333       62.333333
#           Sweden                                   1.066667       76.666667
#           Switzerland                              0.370000       79.666667
#           Turkey                                  31.043333       51.666667
#           United Kingdom                          12.123333       75.000000
# NA        Canada                                   3.673333       73.333333
#           Mexico                                  27.280000       61.666667
#           United States                           10.990000       70.000000
# OC        Australia                               12.840000       73.000000
#           New Zealand                             15.036667       77.000000
# OECD      OECD - Total                            10.786667       68.000000
# SA        Brazil                                   7.006667       61.000000
#           Chile                                    9.316667       62.666667
#           Colombia                                26.006667       67.000000
#
# Unit                                                           ...  \
# Indicator                 Feeling safe walking alone at night  ...
# Continent Country                                              ...
# AF        South Africa                              36.333333  ...
# AS        Israel                                    69.966667  ...
#           Japan                                     72.800000  ...
#           Korea                                     66.666667  ...
# EU        Austria                                   80.700000  ...
#           Belgium                                   70.266667  ...
#           Czech Republic                            72.533333  ...
#           Denmark                                   83.566667  ...
#           Estonia                                   69.633333  ...
#           Finland                                   85.266667  ...
#           France                                    70.700000  ...
#           Germany                                   72.600000  ...
#           Greece                                    60.200000  ...
#           Hungary                                   56.700000  ...
#           Iceland                                   86.300000  ...
#           Ireland                                   76.000000  ...
#           Italy                                     58.600000  ...
#           Latvia                                    63.066667  ...
#           Lithuania                                 56.233333  ...
#           Luxembourg                                75.866667  ...
#           Netherlands                               82.066667  ...
#           Norway                                    90.033333  ...
#           Poland                                    67.466667  ...
#           Portugal                                  73.766667  ...
#           Russia                                    53.466667  ...
#           Slovak Republic                           63.700000  ...
#           Slovenia                                  86.166667  ...
#           Spain                                     82.166667  ...
#           Sweden                                    75.566667  ...
#           Switzerland                               85.333333  ...
#           Turkey                                    59.833333  ...
#           United Kingdom                            77.766667  ...
# NA        Canada                                    82.500000  ...
#           Mexico                                    41.966667  ...
#           United States                             73.900000  ...
# OC        Australia                                 64.133333  ...
#           New Zealand                               66.266667  ...
# OECD      OECD - Total                              68.500000  ...
# SA        Brazil                                    35.866667  ...
#           Chile                                     48.000000  ...
#           Colombia                                  44.566667  ...
#
# Unit                                                                        \
# Indicator                 Self-reported health Voter turnout Water quality
# Continent Country
# AF        South Africa                     NaN          73.0     67.000000
# AS        Israel                     86.750000          72.0     67.000000
#           Japan                      34.800000          53.0     87.000000
#           Korea                      33.000000          77.0     76.000000
# EU        Austria                    70.600000          80.0     92.000000
#           Belgium                    73.600000          89.0     83.666667
#           Czech Republic             60.800000          61.0     86.666667
#           Denmark                    72.600000          86.0     95.000000
#           Estonia                    54.400000          64.0     84.000000
#           Finland                    70.200000          67.0     95.000000
#           France                     66.400000          75.0     81.000000
#           Germany                    65.400000          76.0     91.333333
#           Greece                     76.000000          64.0     69.333333
#           Hungary                    61.000000          70.0     77.000000
#           Iceland                    76.000000          79.0     98.666667
#           Ireland                    82.800000          65.0     85.000000
#           Italy                      71.800000          73.0     71.000000
#           Latvia                     48.000000          59.0     79.333333
#           Lithuania                  45.600000          51.0     80.666667
#           Luxembourg                 69.400000          91.0     84.000000
#           Netherlands                75.800000          82.0     93.000000
#           Norway                     77.200000          78.0     97.666667
#           Poland                     60.000000          55.0     82.000000
#           Portugal                   48.200000          56.0     86.333333
#           Russia                     43.333333          68.0     55.333333
#           Slovak Republic            68.600000          60.0     84.666667
#           Slovenia                   64.400000          53.0     89.666667
#           Spain                      74.000000          70.0     72.333333
#           Sweden                     75.000000          86.0     96.000000
#           Switzerland                77.400000          49.0     95.333333
#           Turkey                     70.400000          86.0     65.000000
#           United Kingdom             70.000000          69.0     83.666667
# NA        Canada                     87.800000          68.0     91.000000
#           Mexico                     65.666667          63.0     67.666667
#           United States              86.800000          65.0     82.666667
# OC        Australia                  87.250000          91.0     92.666667
#           New Zealand                89.250000          80.0     89.000000
# OECD      OECD - Total               69.200000          68.0     81.000000
# SA        Brazil                           NaN          79.0     73.000000
#           Chile                      57.000000          47.0     71.000000
#           Colombia                         NaN          53.0     74.666667
#
# Unit                              Ratio                   \
# Indicator                 Homicide rate Rooms per person
# Continent Country
# AF        South Africa        14.000000              NaN
# AS        Israel               1.833333              1.2
#           Japan                0.200000              1.9
#           Korea                1.000000              1.5
# EU        Austria              0.466667              1.6
#           Belgium              1.033333              2.2
#           Czech Republic       0.500000              1.4
#           Denmark              0.600000              1.9
#           Estonia              3.166667              1.6
#           Finland              1.266667              1.9
#           France               0.466667              1.8
#           Germany              0.500000              1.8
#           Greece               0.833333              1.2
#           Hungary              1.000000              1.2
#           Iceland              0.500000              1.6
#           Ireland              0.666667              2.1
#           Italy                0.600000              1.4
#           Latvia               4.933333              1.2
#           Lithuania            3.433333              1.5
#           Luxembourg           0.566667              1.9
#           Netherlands          0.600000              1.9
#           Norway               0.400000              2.1
#           Poland               0.733333              1.1
#           Portugal             1.000000              1.7
#           Russia               9.933333              0.9
#           Slovak Republic      0.800000              1.1
#           Slovenia             0.600000              1.5
#           Spain                0.600000              1.9
#           Sweden               0.900000              1.7
#           Switzerland          0.600000              1.9
#           Turkey               1.366667              1.0
#           United Kingdom       0.166667              1.9
# NA        Canada               1.266667              2.6
#           Mexico              18.633333              1.0
#           United States        5.500000              2.4
# OC        Australia            1.100000              NaN
#           New Zealand          1.300000              2.4
# OECD      OECD - Total         3.733333              1.8
# SA        Brazil              27.000000              NaN
#           Chile                4.200000              1.2
#           Colombia            25.000000              1.2
#
# Unit                                                     US Dollar  \
# Indicator                 Household net adjusted disposable income
# Continent Country
# AF        South Africa                                         NaN
# AS        Israel                                               NaN
#           Japan                                            29798.0
#           Korea                                            21882.0
# EU        Austria                                          33541.0
#           Belgium                                          30364.0
#           Czech Republic                                   21453.0
#           Denmark                                          29606.0
#           Estonia                                          19697.0
#           Finland                                          29943.0
#           France                                           31304.0
#           Germany                                          34294.0
#           Greece                                           17700.0
#           Hungary                                              NaN
#           Iceland                                              NaN
#           Ireland                                          25310.0
#           Italy                                            26588.0
#           Latvia                                           16275.0
#           Lithuania                                        21660.0
#           Luxembourg                                       39264.0
#           Netherlands                                      29333.0
#           Norway                                           35725.0
#           Poland                                           19814.0
#           Portugal                                         21203.0
#           Russia                                               NaN
#           Slovak Republic                                  20474.0
#           Slovenia                                         20820.0
#           Spain                                            23999.0
#           Sweden                                           31287.0
#           Switzerland                                      37466.0
#           Turkey                                               NaN
#           United Kingdom                                   28715.0
# NA        Canada                                           30854.0
#           Mexico                                               NaN
#           United States                                    45284.0
# OC        Australia                                        32759.0
#           New Zealand                                          NaN
# OECD      OECD - Total                                     33604.0
# SA        Brazil                                               NaN
#           Chile                                                NaN
#           Colombia                                             NaN
#
# Unit                                                              \
# Indicator                 Household net wealth Personal earnings
# Continent Country
# AF        South Africa                     NaN               NaN
# AS        Israel                           NaN           35067.0
#           Japan                       305878.0           40863.0
#           Korea                       285980.0           35191.0
# EU        Austria                     308325.0           50349.0
#           Belgium                     386006.0           49675.0
#           Czech Republic                   NaN           25372.0
#           Denmark                     118637.0           51466.0
#           Estonia                     159373.0           24336.0
#           Finland                     200827.0           42964.0
#           France                      280653.0           43755.0
#           Germany                     259667.0           47585.0
#           Greece                      150134.0           26064.0
#           Hungary                     104458.0           22576.0
#           Iceland                          NaN           61787.0
#           Ireland                     217130.0           47653.0
#           Italy                       279889.0           36658.0
#           Latvia                       70160.0           23683.0
#           Lithuania                        NaN           24287.0
#           Luxembourg                  769053.0           63062.0
#           Netherlands                 157824.0           52877.0
#           Norway                      228936.0           51212.0
#           Poland                      210991.0           27046.0
#           Portugal                    232666.0           25367.0
#           Russia                           NaN               NaN
#           Slovak Republic             119696.0           24328.0
#           Slovenia                    203044.0           34933.0
#           Spain                       373548.0           38507.0
#           Sweden                           NaN           42393.0
#           Switzerland                      NaN           62283.0
#           Turkey                           NaN               NaN
#           United Kingdom              548392.0           43732.0
# NA        Canada                      423849.0           47622.0
#           Mexico                           NaN           15314.0
#           United States               632100.0           60558.0
# OC        Australia                   427064.0           49126.0
#           New Zealand                 388514.0           40043.0
# OECD      OECD - Total                408376.0           43241.0
# SA        Brazil                           NaN               NaN
#           Chile                       100967.0           25879.0
#           Colombia                         NaN               NaN
#
# Unit                                Years
# Indicator                 Life expectancy Years in education
# Continent Country
# AF        South Africa          57.500000                NaN
# AS        Israel                82.466667          15.633333
#           Japan                 84.066667          16.366667
#           Korea                 82.366667          17.266667
# EU        Austria               81.700000          17.000000
#           Belgium               81.500000          19.300000
#           Czech Republic        79.100000          17.900000
#           Denmark               80.900000          19.500000
#           Estonia               77.766667          17.700000
#           Finland               81.500000          19.833333
#           France                82.366667          16.500000
#           Germany               81.066667          18.100000
#           Greece                81.466667          19.000000
#           Hungary               76.166667          16.433333
#           Iceland               82.266667          19.033333
#           Ireland               81.766667          18.100000
#           Italy                 83.300000          16.600000
#           Latvia                74.700000          18.033333
#           Lithuania             74.800000          18.400000
#           Luxembourg            82.766667          15.100000
#           Netherlands           81.600000          18.666667
#           Norway                82.466667          18.333333
#           Poland                77.966667          17.666667
#           Portugal              81.200000          16.933333
#           Russia                71.800000          16.200000
#           Slovak Republic       77.266667          15.766667
#           Slovenia              81.266667          18.366667
#           Spain                 83.400000          17.900000
#           Sweden                82.366667          19.300000
#           Switzerland           83.666667          17.500000
#           Turkey                78.000000          18.300000
#           United Kingdom        81.200000          17.500000
# NA        Canada                81.866667          17.333333
#           Mexico                75.400000          15.166667
#           United States         78.600000          17.200000
# OC        Australia             82.500000          20.966667
#           New Zealand           81.700000          17.700000
# OECD      OECD - Total          80.200000          17.200000
# SA        Brazil                74.766667          16.166667
#           Chile                 79.900000          17.500000
#           Colombia              76.233333          14.100000
#
# [41 rows x 24 columns]

# %%
dataset_multindex.index
# Out:
# MultiIndex([(  'AF',    'South Africa'),
#             (  'AS',          'Israel'),
#             (  'AS',           'Japan'),
#             (  'AS',           'Korea'),
#             (  'EU',         'Austria'),
#             (  'EU',         'Belgium'),
#             (  'EU',  'Czech Republic'),
#             (  'EU',         'Denmark'),
#             (  'EU',         'Estonia'),
#             (  'EU',         'Finland'),
#             (  'EU',          'France'),
#             (  'EU',         'Germany'),
#             (  'EU',          'Greece'),
#             (  'EU',         'Hungary'),
#             (  'EU',         'Iceland'),
#             (  'EU',         'Ireland'),
#             (  'EU',           'Italy'),
#             (  'EU',          'Latvia'),
#             (  'EU',       'Lithuania'),
#             (  'EU',      'Luxembourg'),
#             (  'EU',     'Netherlands'),
#             (  'EU',          'Norway'),
#             (  'EU',          'Poland'),
#             (  'EU',        'Portugal'),
#             (  'EU',          'Russia'),
#             (  'EU', 'Slovak Republic'),
#             (  'EU',        'Slovenia'),
#             (  'EU',           'Spain'),
#             (  'EU',          'Sweden'),
#             (  'EU',     'Switzerland'),
#             (  'EU',          'Turkey'),
#             (  'EU',  'United Kingdom'),
#             (  'NA',          'Canada'),
#             (  'NA',          'Mexico'),
#             (  'NA',   'United States'),
#             (  'OC',       'Australia'),
#             (  'OC',     'New Zealand'),
#             ('OECD',    'OECD - Total'),
#             (  'SA',          'Brazil'),
#             (  'SA',           'Chile'),
#             (  'SA',        'Colombia')],
#            names=['Continent', 'Country'])

# %% [markdown]
# Ojo que las columnas también son Indices!

# %%
dataset_multindex.columns.values
# Out:
# array([('Average score', 'Life satisfaction'),
#        ('Average score', 'Stakeholder engagement for developing regulations'),
#        ('Average score', 'Student skills'),
#        ('Hours', 'Time devoted to leisure and personal care'),
#        ('Micrograms per cubic metre', 'Air pollution'),
#        ('Percentage', 'Dwellings without basic facilities'),
#        ('Percentage', 'Educational attainment'),
#        ('Percentage', 'Employees working very long hours'),
#        ('Percentage', 'Employment rate'),
#        ('Percentage', 'Feeling safe walking alone at night'),
#        ('Percentage', 'Housing expenditure'),
#        ('Percentage', 'Labour market insecurity'),
#        ('Percentage', 'Long-term unemployment rate'),
#        ('Percentage', 'Quality of support network'),
#        ('Percentage', 'Self-reported health'),
#        ('Percentage', 'Voter turnout'), ('Percentage', 'Water quality'),
#        ('Ratio', 'Homicide rate'), ('Ratio', 'Rooms per person'),
#        ('US Dollar', 'Household net adjusted disposable income'),
#        ('US Dollar', 'Household net wealth'),
#        ('US Dollar', 'Personal earnings'), ('Years', 'Life expectancy'),
#        ('Years', 'Years in education')], dtype=object)

# %% [markdown]
# Podemos acceder a los indices de cada nivel usando `get_level_values`

# %%
dataset_multindex.columns.get_level_values(0)
# Out:
# Index(['Average score', 'Average score', 'Average score', 'Hours',
#        'Micrograms per cubic metre', 'Percentage', 'Percentage', 'Percentage',
#        'Percentage', 'Percentage', 'Percentage', 'Percentage', 'Percentage',
#        'Percentage', 'Percentage', 'Percentage', 'Percentage', 'Ratio',
#        'Ratio', 'US Dollar', 'US Dollar', 'US Dollar', 'Years', 'Years'],
#       dtype='object', name='Unit')

# %%
dataset_multindex.columns.get_level_values(1)
# Out:
# Index(['Life satisfaction',
#        'Stakeholder engagement for developing regulations', 'Student skills',
#        'Time devoted to leisure and personal care', 'Air pollution',
#        'Dwellings without basic facilities', 'Educational attainment',
#        'Employees working very long hours', 'Employment rate',
#        'Feeling safe walking alone at night', 'Housing expenditure',
#        'Labour market insecurity', 'Long-term unemployment rate',
#        'Quality of support network', 'Self-reported health', 'Voter turnout',
#        'Water quality', 'Homicide rate', 'Rooms per person',
#        'Household net adjusted disposable income', 'Household net wealth',
#        'Personal earnings', 'Life expectancy', 'Years in education'],
#       dtype='object', name='Indicator')

# %% [markdown]
# También a cierto nivel de las columnas

# %%
dataset_multindex.index.get_level_values(0)
# Out:
# Index(['AF', 'AS', 'AS', 'AS', 'EU', 'EU', 'EU', 'EU', 'EU', 'EU', 'EU', 'EU',
#        'EU', 'EU', 'EU', 'EU', 'EU', 'EU', 'EU', 'EU', 'EU', 'EU', 'EU', 'EU',
#        'EU', 'EU', 'EU', 'EU', 'EU', 'EU', 'EU', 'EU', 'NA', 'NA', 'NA', 'OC',
#        'OC', 'OECD', 'SA', 'SA', 'SA'],
#       dtype='object', name='Continent')

# %%
dataset_multindex.index.get_level_values(1)
# Out:
# Index(['South Africa', 'Israel', 'Japan', 'Korea', 'Austria', 'Belgium',
#        'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany',
#        'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Latvia',
#        'Lithuania', 'Luxembourg', 'Netherlands', 'Norway', 'Poland',
#        'Portugal', 'Russia', 'Slovak Republic', 'Slovenia', 'Spain', 'Sweden',
#        'Switzerland', 'Turkey', 'United Kingdom', 'Canada', 'Mexico',
#        'United States', 'Australia', 'New Zealand', 'OECD - Total', 'Brazil',
#        'Chile', 'Colombia'],
#       dtype='object', name='Country')

# %% [markdown]
# ### Acceder a Multi-Índices

# %% [markdown]
# > **Ejercicio ✏️**: Seleccionar la fila que contiene a Chile

# %%
dataset_multindex.tail(10)
# Out:
# Unit                         Average score  \
# Indicator                Life satisfaction
# Continent Country
# EU        United Kingdom          6.860000
# NA        Canada                  7.425000
#           Mexico                  6.466667
#           United States           7.000000
# OC        Australia               7.350000
#           New Zealand             7.300000
# OECD      OECD - Total            6.480000
# SA        Brazil                  6.400000
#           Chile                   6.480000
#           Colombia                6.266667
#
# Unit                                                                        \
# Indicator                Stakeholder engagement for developing regulations
# Continent Country
# EU        United Kingdom                                               3.1
# NA        Canada                                                       2.9
#           Mexico                                                       3.2
#           United States                                                3.1
# OC        Australia                                                    2.7
#           New Zealand                                                  2.5
# OECD      OECD - Total                                                 2.4
# SA        Brazil                                                       2.2
#           Chile                                                        1.3
#           Colombia                                                     1.4
#
# Unit                                     \
# Indicator                Student skills
# Continent Country
# EU        United Kingdom          502.4
# NA        Canada                  523.2
#           Mexico                  416.0
#           United States           489.4
# OC        Australia               411.2
#           New Zealand             506.2
# OECD      OECD - Total            490.4
# SA        Brazil                  398.2
#           Chile                   443.8
#           Colombia                412.8
#
# Unit                                                         Hours  \
# Indicator                Time devoted to leisure and personal care
# Continent Country
# EU        United Kingdom                                 14.916667
# NA        Canada                                         14.553333
#           Mexico                                               NaN
#           United States                                  14.440000
# OC        Australia                                      14.350000
#           New Zealand                                    14.883333
# OECD      OECD - Total                                   14.896667
# SA        Brazil                                               NaN
#           Chile                                                NaN
#           Colombia                                             NaN
#
# Unit                     Micrograms per cubic metre  \
# Indicator                             Air pollution
# Continent Country
# EU        United Kingdom                       11.0
# NA        Canada                                7.0
#           Mexico                               16.0
#           United States                        10.0
# OC        Australia                             5.0
#           New Zealand                           5.0
# OECD      OECD - Total                         14.0
# SA        Brazil                               10.0
#           Chile                                16.0
#           Colombia                             10.0
#
# Unit                                             Percentage  \
# Indicator                Dwellings without basic facilities
# Continent Country
# EU        United Kingdom                                0.3
# NA        Canada                                        0.2
#           Mexico                                       25.5
#           United States                                 0.1
# OC        Australia                                     NaN
#           New Zealand                                   NaN
# OECD      OECD - Total                                  4.4
# SA        Brazil                                        6.7
#           Chile                                         9.4
#           Colombia                                     23.9
#
# Unit                                             \
# Indicator                Educational attainment
# Continent Country
# EU        United Kingdom              81.000000
# NA        Canada                      91.333333
#           Mexico                      37.666667
#           United States               90.666667
# OC        Australia                   81.000000
#           New Zealand                 78.666667
# OECD      OECD - Total                78.333333
# SA        Brazil                      49.000000
#           Chile                       65.000000
#           Colombia                    54.000000
#
# Unit                                                                        \
# Indicator                Employees working very long hours Employment rate
# Continent Country
# EU        United Kingdom                         12.123333       75.000000
# NA        Canada                                  3.673333       73.333333
#           Mexico                                 27.280000       61.666667
#           United States                          10.990000       70.000000
# OC        Australia                              12.840000       73.000000
#           New Zealand                            15.036667       77.000000
# OECD      OECD - Total                           10.786667       68.000000
# SA        Brazil                                  7.006667       61.000000
#           Chile                                   9.316667       62.666667
#           Colombia                               26.006667       67.000000
#
# Unit                                                          ...  \
# Indicator                Feeling safe walking alone at night  ...
# Continent Country                                             ...
# EU        United Kingdom                           77.766667  ...
# NA        Canada                                   82.500000  ...
#           Mexico                                   41.966667  ...
#           United States                            73.900000  ...
# OC        Australia                                64.133333  ...
#           New Zealand                              66.266667  ...
# OECD      OECD - Total                             68.500000  ...
# SA        Brazil                                   35.866667  ...
#           Chile                                    48.000000  ...
#           Colombia                                 44.566667  ...
#
# Unit                                                                       \
# Indicator                Self-reported health Voter turnout Water quality
# Continent Country
# EU        United Kingdom            70.000000          69.0     83.666667
# NA        Canada                    87.800000          68.0     91.000000
#           Mexico                    65.666667          63.0     67.666667
#           United States             86.800000          65.0     82.666667
# OC        Australia                 87.250000          91.0     92.666667
#           New Zealand               89.250000          80.0     89.000000
# OECD      OECD - Total              69.200000          68.0     81.000000
# SA        Brazil                          NaN          79.0     73.000000
#           Chile                     57.000000          47.0     71.000000
#           Colombia                        NaN          53.0     74.666667
#
# Unit                             Ratio                   \
# Indicator                Homicide rate Rooms per person
# Continent Country
# EU        United Kingdom      0.166667              1.9
# NA        Canada              1.266667              2.6
#           Mexico             18.633333              1.0
#           United States       5.500000              2.4
# OC        Australia           1.100000              NaN
#           New Zealand         1.300000              2.4
# OECD      OECD - Total        3.733333              1.8
# SA        Brazil             27.000000              NaN
#           Chile               4.200000              1.2
#           Colombia           25.000000              1.2
#
# Unit                                                    US Dollar  \
# Indicator                Household net adjusted disposable income
# Continent Country
# EU        United Kingdom                                  28715.0
# NA        Canada                                          30854.0
#           Mexico                                              NaN
#           United States                                   45284.0
# OC        Australia                                       32759.0
#           New Zealand                                         NaN
# OECD      OECD - Total                                    33604.0
# SA        Brazil                                              NaN
#           Chile                                               NaN
#           Colombia                                            NaN
#
# Unit                                                             \
# Indicator                Household net wealth Personal earnings
# Continent Country
# EU        United Kingdom             548392.0           43732.0
# NA        Canada                     423849.0           47622.0
#           Mexico                          NaN           15314.0
#           United States              632100.0           60558.0
# OC        Australia                  427064.0           49126.0
#           New Zealand                388514.0           40043.0
# OECD      OECD - Total               408376.0           43241.0
# SA        Brazil                          NaN               NaN
#           Chile                      100967.0           25879.0
#           Colombia                        NaN               NaN
#
# Unit                               Years
# Indicator                Life expectancy Years in education
# Continent Country
# EU        United Kingdom       81.200000          17.500000
# NA        Canada               81.866667          17.333333
#           Mexico               75.400000          15.166667
#           United States        78.600000          17.200000
# OC        Australia            82.500000          20.966667
#           New Zealand          81.700000          17.700000
# OECD      OECD - Total         80.200000          17.200000
# SA        Brazil               74.766667          16.166667
#           Chile                79.900000          17.500000
#           Colombia             76.233333          14.100000
#
# [10 rows x 24 columns]

# %% [markdown]
# Siempre vamos indexando desde afuera hacia adentro. En este caso, para seleccionar Chile, primero tenemos que seleccionar Sudamerica.

# %%
dataset_multindex.loc[["SA"], :]
# Out:
# Unit                   Average score  \
# Indicator          Life satisfaction
# Continent Country
# SA        Brazil            6.400000
#           Chile             6.480000
#           Colombia          6.266667
#
# Unit                                                                  \
# Indicator          Stakeholder engagement for developing regulations
# Continent Country
# SA        Brazil                                                 2.2
#           Chile                                                  1.3
#           Colombia                                               1.4
#
# Unit                                                                  Hours  \
# Indicator          Student skills Time devoted to leisure and personal care
# Continent Country
# SA        Brazil            398.2                                       NaN
#           Chile             443.8                                       NaN
#           Colombia          412.8                                       NaN
#
# Unit               Micrograms per cubic metre  \
# Indicator                       Air pollution
# Continent Country
# SA        Brazil                         10.0
#           Chile                          16.0
#           Colombia                       10.0
#
# Unit                                       Percentage                         \
# Indicator          Dwellings without basic facilities Educational attainment
# Continent Country
# SA        Brazil                                  6.7                   49.0
#           Chile                                   9.4                   65.0
#           Colombia                               23.9                   54.0
#
# Unit                                                                  \
# Indicator          Employees working very long hours Employment rate
# Continent Country
# SA        Brazil                            7.006667       61.000000
#           Chile                             9.316667       62.666667
#           Colombia                         26.006667       67.000000
#
# Unit                                                    ...  \
# Indicator          Feeling safe walking alone at night  ...
# Continent Country                                       ...
# SA        Brazil                             35.866667  ...
#           Chile                              48.000000  ...
#           Colombia                           44.566667  ...
#
# Unit                                                                 \
# Indicator          Self-reported health Voter turnout Water quality
# Continent Country
# SA        Brazil                    NaN          79.0     73.000000
#           Chile                    57.0          47.0     71.000000
#           Colombia                  NaN          53.0     74.666667
#
# Unit                       Ratio                   \
# Indicator          Homicide rate Rooms per person
# Continent Country
# SA        Brazil            27.0              NaN
#           Chile              4.2              1.2
#           Colombia          25.0              1.2
#
# Unit                                              US Dollar  \
# Indicator          Household net adjusted disposable income
# Continent Country
# SA        Brazil                                        NaN
#           Chile                                         NaN
#           Colombia                                      NaN
#
# Unit                                                                Years  \
# Indicator          Household net wealth Personal earnings Life expectancy
# Continent Country
# SA        Brazil                    NaN               NaN       74.766667
#           Chile                100967.0           25879.0       79.900000
#           Colombia                  NaN               NaN       76.233333
#
# Unit
# Indicator          Years in education
# Continent Country
# SA        Brazil            16.166667
#           Chile             17.500000
#           Colombia          14.100000
#
# [3 rows x 24 columns]

# %% [markdown]
# Luego, usando una tupla, seleccionamos Chile:

# %%
dataset_multindex.loc[[("SA", "Chile")], :]
# Out:
# Unit                  Average score  \
# Indicator         Life satisfaction
# Continent Country
# SA        Chile                6.48
#
# Unit                                                                 \
# Indicator         Stakeholder engagement for developing regulations
# Continent Country
# SA        Chile                                                 1.3
#
# Unit                                                                 Hours  \
# Indicator         Student skills Time devoted to leisure and personal care
# Continent Country
# SA        Chile            443.8                                       NaN
#
# Unit              Micrograms per cubic metre  \
# Indicator                      Air pollution
# Continent Country
# SA        Chile                         16.0
#
# Unit                                      Percentage                         \
# Indicator         Dwellings without basic facilities Educational attainment
# Continent Country
# SA        Chile                                  9.4                   65.0
#
# Unit                                                                 \
# Indicator         Employees working very long hours Employment rate
# Continent Country
# SA        Chile                            9.316667       62.666667
#
# Unit                                                   ...  \
# Indicator         Feeling safe walking alone at night  ...
# Continent Country                                      ...
# SA        Chile                                  48.0  ...
#
# Unit                                                                \
# Indicator         Self-reported health Voter turnout Water quality
# Continent Country
# SA        Chile                   57.0          47.0          71.0
#
# Unit                      Ratio                   \
# Indicator         Homicide rate Rooms per person
# Continent Country
# SA        Chile             4.2              1.2
#
# Unit                                             US Dollar  \
# Indicator         Household net adjusted disposable income
# Continent Country
# SA        Chile                                        NaN
#
# Unit                                                               Years  \
# Indicator         Household net wealth Personal earnings Life expectancy
# Continent Country
# SA        Chile               100967.0           25879.0            79.9
#
# Unit
# Indicator         Years in education
# Continent Country
# SA        Chile                 17.5
#
# [1 rows x 24 columns]

# %% [markdown]
# > **Ejercicio ✏️**: Seleccionar las columnas de los indicadores basados en Porcentajes.

# %% [markdown]
# Mismo caso aquí: Seleccionamos primero el índice externo:

# %%
dataset_multindex.loc[:, ["Percentage"]]
# Out:
# Unit                                              Percentage  \
# Indicator                 Dwellings without basic facilities
# Continent Country
# AF        South Africa                                  37.0
# AS        Israel                                         NaN
#           Japan                                          6.4
#           Korea                                          2.5
# EU        Austria                                        0.9
#           Belgium                                        1.9
#           Czech Republic                                 0.7
#           Denmark                                        0.5
#           Estonia                                        7.0
#           Finland                                        0.5
#           France                                         0.5
#           Germany                                        0.2
#           Greece                                         0.5
#           Hungary                                        4.7
#           Iceland                                        0.0
#           Ireland                                        1.0
#           Italy                                          0.7
#           Latvia                                        13.9
#           Lithuania                                     13.6
#           Luxembourg                                     0.5
#           Netherlands                                    0.1
#           Norway                                         0.0
#           Poland                                         3.0
#           Portugal                                       1.0
#           Russia                                        14.8
#           Slovak Republic                                1.2
#           Slovenia                                       0.4
#           Spain                                          0.1
#           Sweden                                         0.0
#           Switzerland                                    0.1
#           Turkey                                         8.0
#           United Kingdom                                 0.3
# NA        Canada                                         0.2
#           Mexico                                        25.5
#           United States                                  0.1
# OC        Australia                                      NaN
#           New Zealand                                    NaN
# OECD      OECD - Total                                   4.4
# SA        Brazil                                         6.7
#           Chile                                          9.4
#           Colombia                                      23.9
#
# Unit                                              \
# Indicator                 Educational attainment
# Continent Country
# AF        South Africa                 73.333333
# AS        Israel                       87.333333
#           Japan                              NaN
#           Korea                        87.666667
# EU        Austria                      85.000000
#           Belgium                      77.000000
#           Czech Republic               93.666667
#           Denmark                      81.000000
#           Estonia                      88.666667
#           Finland                      88.000000
#           France                       78.333333
#           Germany                      86.666667
#           Greece                       73.000000
#           Hungary                      84.000000
#           Iceland                      77.000000
#           Ireland                      82.000000
#           Italy                        61.000000
#           Latvia                       87.666667
#           Lithuania                    92.666667
#           Luxembourg                   76.666667
#           Netherlands                  78.333333
#           Norway                       82.000000
#           Poland                       92.000000
#           Portugal                     47.666667
#           Russia                       94.000000
#           Slovak Republic              91.333333
#           Slovenia                     88.000000
#           Spain                        59.000000
#           Sweden                       83.000000
#           Switzerland                  87.666667
#           Turkey                       39.000000
#           United Kingdom               81.000000
# NA        Canada                       91.333333
#           Mexico                       37.666667
#           United States                90.666667
# OC        Australia                    81.000000
#           New Zealand                  78.666667
# OECD      OECD - Total                 78.333333
# SA        Brazil                       49.000000
#           Chile                        65.000000
#           Colombia                     54.000000
#
# Unit                                                                         \
# Indicator                 Employees working very long hours Employment rate
# Continent Country
# AF        South Africa                            17.840000       43.333333
# AS        Israel                                  15.273333       69.000000
#           Japan                                         NaN       75.000000
#           Korea                                         NaN       66.666667
# EU        Austria                                  6.590000       72.000000
#           Belgium                                  4.703333       63.333333
#           Czech Republic                           5.496667       73.666667
#           Denmark                                  2.316667       74.000000
#           Estonia                                  2.436667       74.000000
#           Finland                                  3.816667       70.333333
#           France                                   7.656667       65.333333
#           Germany                                  4.196667       75.333333
#           Greece                                   6.280000       53.333333
#           Hungary                                  2.976667       68.000000
#           Iceland                                 14.866667       85.666667
#           Ireland                                  5.260000       67.333333
#           Italy                                    4.003333       58.000000
#           Latvia                                   1.280000       70.000000
#           Lithuania                                0.546667       70.333333
#           Luxembourg                               3.740000       66.333333
#           Netherlands                              0.413333       75.666667
#           Norway                                   2.886667       74.000000
#           Poland                                   5.823333       66.000000
#           Portugal                                 8.340000       68.000000
#           Russia                                   0.140000       70.333333
#           Slovak Republic                          4.073333       66.000000
#           Slovenia                                 4.333333       69.333333
#           Spain                                    3.963333       62.333333
#           Sweden                                   1.066667       76.666667
#           Switzerland                              0.370000       79.666667
#           Turkey                                  31.043333       51.666667
#           United Kingdom                          12.123333       75.000000
# NA        Canada                                   3.673333       73.333333
#           Mexico                                  27.280000       61.666667
#           United States                           10.990000       70.000000
# OC        Australia                               12.840000       73.000000
#           New Zealand                             15.036667       77.000000
# OECD      OECD - Total                            10.786667       68.000000
# SA        Brazil                                   7.006667       61.000000
#           Chile                                    9.316667       62.666667
#           Colombia                                26.006667       67.000000
#
# Unit                                                           \
# Indicator                 Feeling safe walking alone at night
# Continent Country
# AF        South Africa                              36.333333
# AS        Israel                                    69.966667
#           Japan                                     72.800000
#           Korea                                     66.666667
# EU        Austria                                   80.700000
#           Belgium                                   70.266667
#           Czech Republic                            72.533333
#           Denmark                                   83.566667
#           Estonia                                   69.633333
#           Finland                                   85.266667
#           France                                    70.700000
#           Germany                                   72.600000
#           Greece                                    60.200000
#           Hungary                                   56.700000
#           Iceland                                   86.300000
#           Ireland                                   76.000000
#           Italy                                     58.600000
#           Latvia                                    63.066667
#           Lithuania                                 56.233333
#           Luxembourg                                75.866667
#           Netherlands                               82.066667
#           Norway                                    90.033333
#           Poland                                    67.466667
#           Portugal                                  73.766667
#           Russia                                    53.466667
#           Slovak Republic                           63.700000
#           Slovenia                                  86.166667
#           Spain                                     82.166667
#           Sweden                                    75.566667
#           Switzerland                               85.333333
#           Turkey                                    59.833333
#           United Kingdom                            77.766667
# NA        Canada                                    82.500000
#           Mexico                                    41.966667
#           United States                             73.900000
# OC        Australia                                 64.133333
#           New Zealand                               66.266667
# OECD      OECD - Total                              68.500000
# SA        Brazil                                    35.866667
#           Chile                                     48.000000
#           Colombia                                  44.566667
#
# Unit                                                                    \
# Indicator                 Housing expenditure Labour market insecurity
# Continent Country
# AF        South Africa                   18.0                      NaN
# AS        Israel                          NaN                    4.200
#           Japan                          22.0                    2.220
#           Korea                          15.0                    2.302
# EU        Austria                        21.0                    4.076
#           Belgium                        21.0                    4.052
#           Czech Republic                 24.0                    7.208
#           Denmark                        23.0                    4.606
#           Estonia                        17.0                    4.392
#           Finland                        23.0                    4.508
#           France                         21.0                    8.380
#           Germany                        20.0                    4.928
#           Greece                         23.0                   29.200
#           Hungary                        19.0                    5.256
#           Iceland                        24.0                    0.662
#           Ireland                        20.0                    8.784
#           Italy                          23.0                   12.132
#           Latvia                         23.0                   11.316
#           Lithuania                      19.0                      NaN
#           Luxembourg                     21.0                    1.722
#           Netherlands                    19.0                    4.930
#           Norway                         17.0                      NaN
#           Poland                         22.0                    6.984
#           Portugal                       21.0                    9.624
#           Russia                         18.0                      NaN
#           Slovak Republic                23.0                   21.376
#           Slovenia                       18.0                    6.338
#           Spain                          21.0                   23.792
#           Sweden                         19.0                    4.232
#           Switzerland                    22.0                      NaN
#           Turkey                         20.0                   12.060
#           United Kingdom                 26.0                    4.744
# NA        Canada                         22.0                    7.048
#           Mexico                         20.0                    5.396
#           United States                  19.0                    9.072
# OC        Australia                      20.0                    5.922
#           New Zealand                    26.0                    4.700
# OECD      OECD - Total                   20.0                    7.750
# SA        Brazil                          NaN                      NaN
#           Chile                          18.0                    8.168
#           Colombia                       17.0                      NaN
#
# Unit                                                   \
# Indicator                 Long-term unemployment rate
# Continent Country
# AF        South Africa                      16.643333
# AS        Israel                             0.486667
#           Japan                              0.996667
#           Korea                              0.050000
# EU        Austria                            1.830000
#           Belgium                            3.533333
#           Czech Republic                     1.056667
#           Denmark                            1.313333
#           Estonia                            1.916667
#           Finland                            2.123333
#           France                             3.996667
#           Germany                            1.556667
#           Greece                            15.896667
#           Hungary                            1.726667
#           Iceland                            0.256667
#           Ireland                            3.203333
#           Italy                              6.640000
#           Latvia                             3.353333
#           Lithuania                          2.696667
#           Luxembourg                         2.343333
#           Netherlands                        1.976667
#           Norway                             0.656667
#           Poland                             1.513333
#           Portugal                           4.430000
#           Russia                             1.586667
#           Slovak Republic                    4.773333
#           Slovenia                           3.176667
#           Spain                              7.710000
#           Sweden                             1.113333
#           Switzerland                        1.826667
#           Turkey                             2.660000
#           United Kingdom                     1.126667
# NA        Canada                             0.763333
#           Mexico                             0.066667
#           United States                      0.656667
# OC        Australia                          1.306667
#           New Zealand                        0.736667
# OECD      OECD - Total                       1.783333
# SA        Brazil                                  NaN
#           Chile                                   NaN
#           Colombia                           0.820000
#
# Unit                                                                       \
# Indicator                 Quality of support network Self-reported health
# Continent Country
# AF        South Africa                     88.000000                  NaN
# AS        Israel                           88.500000            86.750000
#           Japan                            88.750000            34.800000
#           Korea                            78.333333            33.000000
# EU        Austria                          92.000000            70.600000
#           Belgium                          92.000000            73.600000
#           Czech Republic                   91.750000            60.800000
#           Denmark                          95.500000            72.600000
#           Estonia                          91.200000            54.400000
#           Finland                          94.800000            70.200000
#           France                           89.000000            66.400000
#           Germany                          90.500000            65.400000
#           Greece                           78.800000            76.000000
#           Hungary                          85.500000            61.000000
#           Iceland                          98.000000            76.000000
#           Ireland                          95.000000            82.800000
#           Italy                            91.800000            71.800000
#           Latvia                           86.200000            48.000000
#           Lithuania                        88.400000            45.600000
#           Luxembourg                       93.000000            69.400000
#           Netherlands                      91.000000            75.800000
#           Norway                           94.000000            77.200000
#           Poland                           86.000000            60.000000
#           Portugal                         88.000000            48.200000
#           Russia                           90.000000            43.333333
#           Slovak Republic                  91.500000            68.600000
#           Slovenia                         91.666667            64.400000
#           Spain                            92.750000            74.000000
#           Sweden                           91.500000            75.000000
#           Switzerland                      93.333333            77.400000
#           Turkey                           86.000000            70.400000
#           United Kingdom                   94.000000            70.000000
# NA        Canada                           93.250000            87.800000
#           Mexico                           81.600000            65.666667
#           United States                    91.750000            86.800000
# OC        Australia                        95.250000            87.250000
#           New Zealand                      96.250000            89.250000
# OECD      OECD - Total                     88.400000            69.200000
# SA        Brazil                           89.250000                  NaN
#           Chile                            84.600000            57.000000
#           Colombia                         89.000000                  NaN
#
# Unit
# Indicator                 Voter turnout Water quality
# Continent Country
# AF        South Africa             73.0     67.000000
# AS        Israel                   72.0     67.000000
#           Japan                    53.0     87.000000
#           Korea                    77.0     76.000000
# EU        Austria                  80.0     92.000000
#           Belgium                  89.0     83.666667
#           Czech Republic           61.0     86.666667
#           Denmark                  86.0     95.000000
#           Estonia                  64.0     84.000000
#           Finland                  67.0     95.000000
#           France                   75.0     81.000000
#           Germany                  76.0     91.333333
#           Greece                   64.0     69.333333
#           Hungary                  70.0     77.000000
#           Iceland                  79.0     98.666667
#           Ireland                  65.0     85.000000
#           Italy                    73.0     71.000000
#           Latvia                   59.0     79.333333
#           Lithuania                51.0     80.666667
#           Luxembourg               91.0     84.000000
#           Netherlands              82.0     93.000000
#           Norway                   78.0     97.666667
#           Poland                   55.0     82.000000
#           Portugal                 56.0     86.333333
#           Russia                   68.0     55.333333
#           Slovak Republic          60.0     84.666667
#           Slovenia                 53.0     89.666667
#           Spain                    70.0     72.333333
#           Sweden                   86.0     96.000000
#           Switzerland              49.0     95.333333
#           Turkey                   86.0     65.000000
#           United Kingdom           69.0     83.666667
# NA        Canada                   68.0     91.000000
#           Mexico                   63.0     67.666667
#           United States            65.0     82.666667
# OC        Australia                91.0     92.666667
#           New Zealand              80.0     89.000000
# OECD      OECD - Total             68.0     81.000000
# SA        Brazil                   79.0     73.000000
#           Chile                    47.0     71.000000
#           Colombia                 53.0     74.666667

# %% [markdown]
# > **Ejercicio ✏️**: Seleccionar la columna que contiene a Life expectancy

# %%
dataset_multindex.loc[:, [("Years", "Life expectancy")]]
# Out:
# Unit                                Years
# Indicator                 Life expectancy
# Continent Country
# AF        South Africa          57.500000
# AS        Israel                82.466667
#           Japan                 84.066667
#           Korea                 82.366667
# EU        Austria               81.700000
#           Belgium               81.500000
#           Czech Republic        79.100000
#           Denmark               80.900000
#           Estonia               77.766667
#           Finland               81.500000
#           France                82.366667
#           Germany               81.066667
#           Greece                81.466667
#           Hungary               76.166667
#           Iceland               82.266667
#           Ireland               81.766667
#           Italy                 83.300000
#           Latvia                74.700000
#           Lithuania             74.800000
#           Luxembourg            82.766667
#           Netherlands           81.600000
#           Norway                82.466667
#           Poland                77.966667
#           Portugal              81.200000
#           Russia                71.800000
#           Slovak Republic       77.266667
#           Slovenia              81.266667
#           Spain                 83.400000
#           Sweden                82.366667
#           Switzerland           83.666667
#           Turkey                78.000000
#           United Kingdom        81.200000
# NA        Canada                81.866667
#           Mexico                75.400000
#           United States         78.600000
# OC        Australia             82.500000
#           New Zealand           81.700000
# OECD      OECD - Total          80.200000
# SA        Brazil                74.766667
#           Chile                 79.900000
#           Colombia              76.233333

# %% [markdown]
# > **Ejercicio ✏️**: Seleccionar la fila que contiene a Chile y la columna que contiene a Life expectancy

# %%
dataset_multindex.loc[[("SA", "Chile")], [("Years", "Life expectancy")]]

# %% [markdown]
# > **Pregunta ❓**: ¿Cómo puedo solicitar `Housing expenditure` como `Employment rate` al mismo tiempo?

# %%
dataset_multindex.head()

# %%
dataset_multindex.loc[
    :, [("Percentage", "Housing expenditure"), ("Percentage", "Employment rate")]
]
# Out:
# Unit                               Percentage
# Indicator                 Housing expenditure Employment rate
# Continent Country
# AF        South Africa                   18.0       43.333333
# AS        Israel                          NaN       69.000000
#           Japan                          22.0       75.000000
#           Korea                          15.0       66.666667
# EU        Austria                        21.0       72.000000
#           Belgium                        21.0       63.333333
#           Czech Republic                 24.0       73.666667
#           Denmark                        23.0       74.000000
#           Estonia                        17.0       74.000000
#           Finland                        23.0       70.333333
#           France                         21.0       65.333333
#           Germany                        20.0       75.333333
#           Greece                         23.0       53.333333
#           Hungary                        19.0       68.000000
#           Iceland                        24.0       85.666667
#           Ireland                        20.0       67.333333
#           Italy                          23.0       58.000000
#           Latvia                         23.0       70.000000
#           Lithuania                      19.0       70.333333
#           Luxembourg                     21.0       66.333333
#           Netherlands                    19.0       75.666667
#           Norway                         17.0       74.000000
#           Poland                         22.0       66.000000
#           Portugal                       21.0       68.000000
#           Russia                         18.0       70.333333
#           Slovak Republic                23.0       66.000000
#           Slovenia                       18.0       69.333333
#           Spain                          21.0       62.333333
#           Sweden                         19.0       76.666667
#           Switzerland                    22.0       79.666667
#           Turkey                         20.0       51.666667
#           United Kingdom                 26.0       75.000000
# NA        Canada                         22.0       73.333333
#           Mexico                         20.0       61.666667
#           United States                  19.0       70.000000
# OC        Australia                      20.0       73.000000
#           New Zealand                    26.0       77.000000
# OECD      OECD - Total                   20.0       68.000000
# SA        Brazil                          NaN       61.000000
#           Chile                          18.0       62.666667
#           Colombia                       17.0       67.000000

# %%
dataset_multindex.loc[
    :, [("Percentage", ["Housing expenditure", "Employment rate"])]
]
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/common.py:241: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/categorical.py in __init__(self, values, categories, ordered, dtype, fastpath, copy)
#     431             try:
# --> 432                 codes, categories = factorize(values, sort=True)
#     433             except TypeError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/algorithms.py in factorize(values, sort, na_sentinel, size_hint)
#     761         codes, uniques = factorize_array(
# --> 762             values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     763         )
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/algorithms.py in factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     563     uniques, codes = table.factorize(
# --> 564         values, na_sentinel=na_sentinel, na_value=na_value, mask=mask
#     565     )
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/multi.py in _get_indexer(self, target, method, limit, tolerance)
#    2662             try:
# -> 2663                 target = MultiIndex.from_tuples(target)
#    2664             except (TypeError, ValueError):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/multi.py in new_meth(self_or_cls, *args, **kwargs)
#     201
# --> 202         return meth(self_or_cls, *args, **kwargs)
#     203
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/multi.py in from_tuples(cls, tuples, sortorder, names)
#     559
# --> 560         return cls.from_arrays(arrays, sortorder=sortorder, names=names)
#     561
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/multi.py in from_arrays(cls, arrays, sortorder, names)
#     482
# --> 483         codes, levels = factorize_from_iterables(arrays)
#     484         if names is lib.no_default:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/categorical.py in factorize_from_iterables(iterables)
#    2781
# -> 2782     codes, categories = zip(*(factorize_from_iterable(it) for it in iterables))
#    2783     return list(codes), list(categories)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/categorical.py in <genexpr>(.0)
#    2781
# -> 2782     codes, categories = zip(*(factorize_from_iterable(it) for it in iterables))
#    2783     return list(codes), list(categories)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/categorical.py in factorize_from_iterable(values)
#    2754         # from ordered. Set ordered to False as default. See GH #15457
# -> 2755         cat = Categorical(values, ordered=False)
#    2756         categories = cat.categories
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/categorical.py in __init__(self, values, categories, ordered, dtype, fastpath, copy)
#     433             except TypeError as err:
# --> 434                 codes, categories = factorize(values, sort=False)
#     435                 if dtype.ordered:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/algorithms.py in factorize(values, sort, na_sentinel, size_hint)
#     761         codes, uniques = factorize_array(
# --> 762             values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     763         )
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/algorithms.py in factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     563     uniques, codes = table.factorize(
# --> 564         values, na_sentinel=na_sentinel, na_value=na_value, mask=mask
#     565     )
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-6b5fcd4b2e65> in <module>
#       1 dataset_multindex.loc[
# ----> 2     :, [("Percentage", ["Housing expenditure", "Employment rate"])]
#       3 ]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1098     def _getitem_tuple(self, tup: tuple):
#    1099         with suppress(IndexingError):
# -> 1100             return self._getitem_lowerdim(tup)
#    1101
#    1102         # no multi-index, so validate all of the indexers
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     820         # we may have a nested tuples indexer here
#     821         if self._is_nested_tuple_indexer(tup):
# --> 822             return self._getitem_nested_tuple(tup)
#     823
#     824         # we maybe be using a tuple to represent multiple dimensions here
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_nested_tuple(self, tup)
#     904                 continue
#     905
# --> 906             obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#     907             axis -= 1
#     908
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1091
#    1092         # A collection of keys
# -> 1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1094         return self.obj._reindex_with_indexers(
#    1095             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1307
#    1308         if ax._index_as_unique:
# -> 1309             indexer = ax.get_indexer_for(keyarr)
#    1310             keyarr = ax.reindex(keyarr)[0]
#    1311         else:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_indexer_for(self, target, **kwargs)
#    5273         """
#    5274         if self._index_as_unique:
# -> 5275             return self.get_indexer(target, **kwargs)
#    5276         indexer, _ = self.get_indexer_non_unique(target)
#    5277         return indexer
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3484             )
#    3485
# -> 3486         return self._get_indexer(target, method, limit, tolerance)
#    3487
#    3488     def _get_indexer(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/multi.py in _get_indexer(self, target, method, limit, tolerance)
#    2667                 if method is None:
#    2668                     return Index(self._values).get_indexer(
# -> 2669                         target, method=method, limit=limit, tolerance=tolerance
#    2670                     )
#    2671
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3484             )
#    3485
# -> 3486         return self._get_indexer(target, method, limit, tolerance)
#    3487
#    3488     def _get_indexer(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in _get_indexer(self, target, method, limit, tolerance)
#    3510             indexer = self._get_nearest_indexer(target, limit, tolerance)
#    3511         else:
# -> 3512             indexer = self._engine.get_indexer(target._get_engine_target())
#    3513
#    3514         return ensure_platform_int(indexer)
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_indexer()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# Este caso puede convertirse en un problema cuando sacamos muchas columnas, ya que tendremos que escribir muchas tuplas.

# %% [markdown]
# #### Opción: `IndexSlice`
#
# `IndexSlice` soluciona el problema anteriormente mencionado al permitir seleccionar más de un índice/columna por nivel:

# %%
idx = pd.IndexSlice

dataset_multindex.loc[
    :, idx["Percentage", ["Employees working very long hours", "Housing expenditure"]]
]
# Out:
# Unit                                             Percentage  \
# Indicator                 Employees working very long hours
# Continent Country
# AF        South Africa                            17.840000
# AS        Israel                                  15.273333
#           Japan                                         NaN
#           Korea                                         NaN
# EU        Austria                                  6.590000
#           Belgium                                  4.703333
#           Czech Republic                           5.496667
#           Denmark                                  2.316667
#           Estonia                                  2.436667
#           Finland                                  3.816667
#           France                                   7.656667
#           Germany                                  4.196667
#           Greece                                   6.280000
#           Hungary                                  2.976667
#           Iceland                                 14.866667
#           Ireland                                  5.260000
#           Italy                                    4.003333
#           Latvia                                   1.280000
#           Lithuania                                0.546667
#           Luxembourg                               3.740000
#           Netherlands                              0.413333
#           Norway                                   2.886667
#           Poland                                   5.823333
#           Portugal                                 8.340000
#           Russia                                   0.140000
#           Slovak Republic                          4.073333
#           Slovenia                                 4.333333
#           Spain                                    3.963333
#           Sweden                                   1.066667
#           Switzerland                              0.370000
#           Turkey                                  31.043333
#           United Kingdom                          12.123333
# NA        Canada                                   3.673333
#           Mexico                                  27.280000
#           United States                           10.990000
# OC        Australia                               12.840000
#           New Zealand                             15.036667
# OECD      OECD - Total                            10.786667
# SA        Brazil                                   7.006667
#           Chile                                    9.316667
#           Colombia                                26.006667
#
# Unit
# Indicator                 Housing expenditure
# Continent Country
# AF        South Africa                   18.0
# AS        Israel                          NaN
#           Japan                          22.0
#           Korea                          15.0
# EU        Austria                        21.0
#           Belgium                        21.0
#           Czech Republic                 24.0
#           Denmark                        23.0
#           Estonia                        17.0
#           Finland                        23.0
#           France                         21.0
#           Germany                        20.0
#           Greece                         23.0
#           Hungary                        19.0
#           Iceland                        24.0
#           Ireland                        20.0
#           Italy                          23.0
#           Latvia                         23.0
#           Lithuania                      19.0
#           Luxembourg                     21.0
#           Netherlands                    19.0
#           Norway                         17.0
#           Poland                         22.0
#           Portugal                       21.0
#           Russia                         18.0
#           Slovak Republic                23.0
#           Slovenia                       18.0
#           Spain                          21.0
#           Sweden                         19.0
#           Switzerland                    22.0
#           Turkey                         20.0
#           United Kingdom                 26.0
# NA        Canada                         22.0
#           Mexico                         20.0
#           United States                  19.0
# OC        Australia                      20.0
#           New Zealand                    26.0
# OECD      OECD - Total                   20.0
# SA        Brazil                          NaN
#           Chile                          18.0
#           Colombia                       17.0

# %% [markdown]
# Lo siguiente extiende el ejemplo anterior para seleccionar los paises de Norte y Sudamerica.

# %%
dataset_multindex.loc[
    idx[["NA", "SA"]],
    idx["Percentage", ["Employees working very long hours", "Housing expenditure"]],
]
# Out:
# Unit                                           Percentage
# Indicator               Employees working very long hours Housing expenditure
# Continent Country
# NA        Canada                                 3.673333                22.0
#           Mexico                                27.280000                20.0
#           United States                         10.990000                19.0
# SA        Brazil                                 7.006667                 NaN
#           Chile                                  9.316667                18.0
#           Colombia                              26.006667                17.0

# %% [markdown]
# Incluso, puede pedir más de un índice/columna por cada nivel:

# %%
dataset_multindex.loc[
    :,
    idx[
        ["Hours", "Percentage"],
        [
            "Time devoted to leisure and personal care",
            "Employees working very long hours",
            "Housing expenditure",
        ],
    ],
]
# Out:
# Unit                                                          Hours  \
# Indicator                 Time devoted to leisure and personal care
# Continent Country
# AF        South Africa                                    14.770000
# AS        Israel                                                NaN
#           Japan                                                 NaN
#           Korea                                           14.583333
# EU        Austria                                         14.530000
#           Belgium                                         15.663333
#           Czech Republic                                        NaN
#           Denmark                                         15.873333
#           Estonia                                         14.886667
#           Finland                                         15.163333
#           France                                          16.336667
#           Germany                                         15.613333
#           Greece                                                NaN
#           Hungary                                               NaN
#           Iceland                                               NaN
#           Ireland                                               NaN
#           Italy                                           16.313333
#           Latvia                                          13.826667
#           Lithuania                                             NaN
#           Luxembourg                                            NaN
#           Netherlands                                           NaN
#           Norway                                          15.563333
#           Poland                                          14.390000
#           Portugal                                              NaN
#           Russia                                                NaN
#           Slovak Republic                                       NaN
#           Slovenia                                        14.730000
#           Spain                                           15.860000
#           Sweden                                          15.176667
#           Switzerland                                           NaN
#           Turkey                                          14.653333
#           United Kingdom                                  14.916667
# NA        Canada                                          14.553333
#           Mexico                                                NaN
#           United States                                   14.440000
# OC        Australia                                       14.350000
#           New Zealand                                     14.883333
# OECD      OECD - Total                                    14.896667
# SA        Brazil                                                NaN
#           Chile                                                 NaN
#           Colombia                                              NaN
#
# Unit                                             Percentage  \
# Indicator                 Employees working very long hours
# Continent Country
# AF        South Africa                            17.840000
# AS        Israel                                  15.273333
#           Japan                                         NaN
#           Korea                                         NaN
# EU        Austria                                  6.590000
#           Belgium                                  4.703333
#           Czech Republic                           5.496667
#           Denmark                                  2.316667
#           Estonia                                  2.436667
#           Finland                                  3.816667
#           France                                   7.656667
#           Germany                                  4.196667
#           Greece                                   6.280000
#           Hungary                                  2.976667
#           Iceland                                 14.866667
#           Ireland                                  5.260000
#           Italy                                    4.003333
#           Latvia                                   1.280000
#           Lithuania                                0.546667
#           Luxembourg                               3.740000
#           Netherlands                              0.413333
#           Norway                                   2.886667
#           Poland                                   5.823333
#           Portugal                                 8.340000
#           Russia                                   0.140000
#           Slovak Republic                          4.073333
#           Slovenia                                 4.333333
#           Spain                                    3.963333
#           Sweden                                   1.066667
#           Switzerland                              0.370000
#           Turkey                                  31.043333
#           United Kingdom                          12.123333
# NA        Canada                                   3.673333
#           Mexico                                  27.280000
#           United States                           10.990000
# OC        Australia                               12.840000
#           New Zealand                             15.036667
# OECD      OECD - Total                            10.786667
# SA        Brazil                                   7.006667
#           Chile                                    9.316667
#           Colombia                                26.006667
#
# Unit
# Indicator                 Housing expenditure
# Continent Country
# AF        South Africa                   18.0
# AS        Israel                          NaN
#           Japan                          22.0
#           Korea                          15.0
# EU        Austria                        21.0
#           Belgium                        21.0
#           Czech Republic                 24.0
#           Denmark                        23.0
#           Estonia                        17.0
#           Finland                        23.0
#           France                         21.0
#           Germany                        20.0
#           Greece                         23.0
#           Hungary                        19.0
#           Iceland                        24.0
#           Ireland                        20.0
#           Italy                          23.0
#           Latvia                         23.0
#           Lithuania                      19.0
#           Luxembourg                     21.0
#           Netherlands                    19.0
#           Norway                         17.0
#           Poland                         22.0
#           Portugal                       21.0
#           Russia                         18.0
#           Slovak Republic                23.0
#           Slovenia                       18.0
#           Spain                          21.0
#           Sweden                         19.0
#           Switzerland                    22.0
#           Turkey                         20.0
#           United Kingdom                 26.0
# NA        Canada                         22.0
#           Mexico                         20.0
#           United States                  19.0
# OC        Australia                      20.0
#           New Zealand                    26.0
# OECD      OECD - Total                   20.0
# SA        Brazil                          NaN
#           Chile                          18.0
#           Colombia                       17.0

# %% [markdown]
# ### `droplevel`
#
# El método `droplevel` nos permite eliminar un nivel de un multi-índice, tanto para filas como para columnas.
# Recibe como parámetros el nivel (partiendo por 0 desde afuera hacia adentro) y el eje (axis):

# %%
dataset_multindex
# Out:
# Unit                          Average score  \
# Indicator                 Life satisfaction
# Continent Country
# AF        South Africa             4.700000
# AS        Israel                   7.225000
#           Japan                    5.900000
#           Korea                    5.866667
# EU        Austria                  7.225000
#           Belgium                  7.000000
#           Czech Republic           6.700000
#           Denmark                  7.650000
#           Estonia                  5.780000
#           Finland                  7.660000
#           France                   6.540000
#           Germany                  7.100000
#           Greece                   5.340000
#           Hungary                  5.680000
#           Iceland                  7.580000
#           Ireland                  7.050000
#           Italy                    6.140000
#           Latvia                   5.940000
#           Lithuania                5.980000
#           Luxembourg               6.900000
#           Netherlands              7.500000
#           Norway                   7.620000
#           Poland                   6.100000
#           Portugal                 5.480000
#           Russia                   5.880000
#           Slovak Republic          6.425000
#           Slovenia                 5.933333
#           Spain                    6.225000
#           Sweden                   7.400000
#           Switzerland              7.500000
#           Turkey                   5.520000
#           United Kingdom           6.860000
# NA        Canada                   7.425000
#           Mexico                   6.466667
#           United States            7.000000
# OC        Australia                7.350000
#           New Zealand              7.300000
# OECD      OECD - Total             6.480000
# SA        Brazil                   6.400000
#           Chile                    6.480000
#           Colombia                 6.266667
#
# Unit                                                                         \
# Indicator                 Stakeholder engagement for developing regulations
# Continent Country
# AF        South Africa                                                  NaN
# AS        Israel                                                        2.5
#           Japan                                                         1.4
#           Korea                                                         2.9
# EU        Austria                                                       1.3
#           Belgium                                                       2.0
#           Czech Republic                                                1.6
#           Denmark                                                       2.0
#           Estonia                                                       2.7
#           Finland                                                       2.2
#           France                                                        2.1
#           Germany                                                       1.8
#           Greece                                                        1.8
#           Hungary                                                       1.2
#           Iceland                                                       2.1
#           Ireland                                                       1.3
#           Italy                                                         2.5
#           Latvia                                                        2.2
#           Lithuania                                                     2.4
#           Luxembourg                                                    1.7
#           Netherlands                                                   2.6
#           Norway                                                        2.2
#           Poland                                                        2.6
#           Portugal                                                      1.5
#           Russia                                                        NaN
#           Slovak Republic                                               3.0
#           Slovenia                                                      2.5
#           Spain                                                         1.8
#           Sweden                                                        2.0
#           Switzerland                                                   2.3
#           Turkey                                                        1.5
#           United Kingdom                                                3.1
# NA        Canada                                                        2.9
#           Mexico                                                        3.2
#           United States                                                 3.1
# OC        Australia                                                     2.7
#           New Zealand                                                   2.5
# OECD      OECD - Total                                                  2.4
# SA        Brazil                                                        2.2
#           Chile                                                         1.3
#           Colombia                                                      1.4
#
# Unit                                      \
# Indicator                 Student skills
# Continent Country
# AF        South Africa               NaN
# AS        Israel                   470.0
#           Japan                    528.8
#           Korea                    520.0
# EU        Austria                  492.8
#           Belgium                  503.8
#           Czech Republic           492.2
#           Denmark                  505.2
#           Estonia                  525.8
#           Finland                  523.6
#           France                   497.4
#           Germany                  511.0
#           Greece                   460.2
#           Hungary                  475.0
#           Iceland                  480.8
#           Ireland                  509.8
#           Italy                    485.0
#           Latvia                   487.6
#           Lithuania                476.6
#           Luxembourg               485.4
#           Netherlands              509.6
#           Norway                   504.8
#           Poland                   505.4
#           Portugal                 499.4
#           Russia                   491.8
#           Slovak Republic          463.4
#           Slovenia                 510.4
#           Spain                    492.4
#           Sweden                   497.0
#           Switzerland              507.4
#           Turkey                   426.8
#           United Kingdom           502.4
# NA        Canada                   523.2
#           Mexico                   416.0
#           United States            489.4
# OC        Australia                411.2
#           New Zealand              506.2
# OECD      OECD - Total             490.4
# SA        Brazil                   398.2
#           Chile                    443.8
#           Colombia                 412.8
#
# Unit                                                          Hours  \
# Indicator                 Time devoted to leisure and personal care
# Continent Country
# AF        South Africa                                    14.770000
# AS        Israel                                                NaN
#           Japan                                                 NaN
#           Korea                                           14.583333
# EU        Austria                                         14.530000
#           Belgium                                         15.663333
#           Czech Republic                                        NaN
#           Denmark                                         15.873333
#           Estonia                                         14.886667
#           Finland                                         15.163333
#           France                                          16.336667
#           Germany                                         15.613333
#           Greece                                                NaN
#           Hungary                                               NaN
#           Iceland                                               NaN
#           Ireland                                               NaN
#           Italy                                           16.313333
#           Latvia                                          13.826667
#           Lithuania                                             NaN
#           Luxembourg                                            NaN
#           Netherlands                                           NaN
#           Norway                                          15.563333
#           Poland                                          14.390000
#           Portugal                                              NaN
#           Russia                                                NaN
#           Slovak Republic                                       NaN
#           Slovenia                                        14.730000
#           Spain                                           15.860000
#           Sweden                                          15.176667
#           Switzerland                                           NaN
#           Turkey                                          14.653333
#           United Kingdom                                  14.916667
# NA        Canada                                          14.553333
#           Mexico                                                NaN
#           United States                                   14.440000
# OC        Australia                                       14.350000
#           New Zealand                                     14.883333
# OECD      OECD - Total                                    14.896667
# SA        Brazil                                                NaN
#           Chile                                                 NaN
#           Colombia                                              NaN
#
# Unit                      Micrograms per cubic metre  \
# Indicator                              Air pollution
# Continent Country
# AF        South Africa                          22.0
# AS        Israel                                21.0
#           Japan                                 14.0
#           Korea                                 28.0
# EU        Austria                               16.0
#           Belgium                               15.0
#           Czech Republic                        20.0
#           Denmark                                9.0
#           Estonia                                8.0
#           Finland                                6.0
#           France                                13.0
#           Germany                               14.0
#           Greece                                18.0
#           Hungary                               19.0
#           Iceland                                3.0
#           Ireland                                7.0
#           Italy                                 18.0
#           Latvia                                11.0
#           Lithuania                             14.0
#           Luxembourg                            12.0
#           Netherlands                           14.0
#           Norway                                 5.0
#           Poland                                22.0
#           Portugal                              10.0
#           Russia                                15.0
#           Slovak Republic                       21.0
#           Slovenia                              16.0
#           Spain                                 11.0
#           Sweden                                 6.0
#           Switzerland                           15.0
#           Turkey                                20.0
#           United Kingdom                        11.0
# NA        Canada                                 7.0
#           Mexico                                16.0
#           United States                         10.0
# OC        Australia                              5.0
#           New Zealand                            5.0
# OECD      OECD - Total                          14.0
# SA        Brazil                                10.0
#           Chile                                 16.0
#           Colombia                              10.0
#
# Unit                                              Percentage  \
# Indicator                 Dwellings without basic facilities
# Continent Country
# AF        South Africa                                  37.0
# AS        Israel                                         NaN
#           Japan                                          6.4
#           Korea                                          2.5
# EU        Austria                                        0.9
#           Belgium                                        1.9
#           Czech Republic                                 0.7
#           Denmark                                        0.5
#           Estonia                                        7.0
#           Finland                                        0.5
#           France                                         0.5
#           Germany                                        0.2
#           Greece                                         0.5
#           Hungary                                        4.7
#           Iceland                                        0.0
#           Ireland                                        1.0
#           Italy                                          0.7
#           Latvia                                        13.9
#           Lithuania                                     13.6
#           Luxembourg                                     0.5
#           Netherlands                                    0.1
#           Norway                                         0.0
#           Poland                                         3.0
#           Portugal                                       1.0
#           Russia                                        14.8
#           Slovak Republic                                1.2
#           Slovenia                                       0.4
#           Spain                                          0.1
#           Sweden                                         0.0
#           Switzerland                                    0.1
#           Turkey                                         8.0
#           United Kingdom                                 0.3
# NA        Canada                                         0.2
#           Mexico                                        25.5
#           United States                                  0.1
# OC        Australia                                      NaN
#           New Zealand                                    NaN
# OECD      OECD - Total                                   4.4
# SA        Brazil                                         6.7
#           Chile                                          9.4
#           Colombia                                      23.9
#
# Unit                                              \
# Indicator                 Educational attainment
# Continent Country
# AF        South Africa                 73.333333
# AS        Israel                       87.333333
#           Japan                              NaN
#           Korea                        87.666667
# EU        Austria                      85.000000
#           Belgium                      77.000000
#           Czech Republic               93.666667
#           Denmark                      81.000000
#           Estonia                      88.666667
#           Finland                      88.000000
#           France                       78.333333
#           Germany                      86.666667
#           Greece                       73.000000
#           Hungary                      84.000000
#           Iceland                      77.000000
#           Ireland                      82.000000
#           Italy                        61.000000
#           Latvia                       87.666667
#           Lithuania                    92.666667
#           Luxembourg                   76.666667
#           Netherlands                  78.333333
#           Norway                       82.000000
#           Poland                       92.000000
#           Portugal                     47.666667
#           Russia                       94.000000
#           Slovak Republic              91.333333
#           Slovenia                     88.000000
#           Spain                        59.000000
#           Sweden                       83.000000
#           Switzerland                  87.666667
#           Turkey                       39.000000
#           United Kingdom               81.000000
# NA        Canada                       91.333333
#           Mexico                       37.666667
#           United States                90.666667
# OC        Australia                    81.000000
#           New Zealand                  78.666667
# OECD      OECD - Total                 78.333333
# SA        Brazil                       49.000000
#           Chile                        65.000000
#           Colombia                     54.000000
#
# Unit                                                                         \
# Indicator                 Employees working very long hours Employment rate
# Continent Country
# AF        South Africa                            17.840000       43.333333
# AS        Israel                                  15.273333       69.000000
#           Japan                                         NaN       75.000000
#           Korea                                         NaN       66.666667
# EU        Austria                                  6.590000       72.000000
#           Belgium                                  4.703333       63.333333
#           Czech Republic                           5.496667       73.666667
#           Denmark                                  2.316667       74.000000
#           Estonia                                  2.436667       74.000000
#           Finland                                  3.816667       70.333333
#           France                                   7.656667       65.333333
#           Germany                                  4.196667       75.333333
#           Greece                                   6.280000       53.333333
#           Hungary                                  2.976667       68.000000
#           Iceland                                 14.866667       85.666667
#           Ireland                                  5.260000       67.333333
#           Italy                                    4.003333       58.000000
#           Latvia                                   1.280000       70.000000
#           Lithuania                                0.546667       70.333333
#           Luxembourg                               3.740000       66.333333
#           Netherlands                              0.413333       75.666667
#           Norway                                   2.886667       74.000000
#           Poland                                   5.823333       66.000000
#           Portugal                                 8.340000       68.000000
#           Russia                                   0.140000       70.333333
#           Slovak Republic                          4.073333       66.000000
#           Slovenia                                 4.333333       69.333333
#           Spain                                    3.963333       62.333333
#           Sweden                                   1.066667       76.666667
#           Switzerland                              0.370000       79.666667
#           Turkey                                  31.043333       51.666667
#           United Kingdom                          12.123333       75.000000
# NA        Canada                                   3.673333       73.333333
#           Mexico                                  27.280000       61.666667
#           United States                           10.990000       70.000000
# OC        Australia                               12.840000       73.000000
#           New Zealand                             15.036667       77.000000
# OECD      OECD - Total                            10.786667       68.000000
# SA        Brazil                                   7.006667       61.000000
#           Chile                                    9.316667       62.666667
#           Colombia                                26.006667       67.000000
#
# Unit                                                           ...  \
# Indicator                 Feeling safe walking alone at night  ...
# Continent Country                                              ...
# AF        South Africa                              36.333333  ...
# AS        Israel                                    69.966667  ...
#           Japan                                     72.800000  ...
#           Korea                                     66.666667  ...
# EU        Austria                                   80.700000  ...
#           Belgium                                   70.266667  ...
#           Czech Republic                            72.533333  ...
#           Denmark                                   83.566667  ...
#           Estonia                                   69.633333  ...
#           Finland                                   85.266667  ...
#           France                                    70.700000  ...
#           Germany                                   72.600000  ...
#           Greece                                    60.200000  ...
#           Hungary                                   56.700000  ...
#           Iceland                                   86.300000  ...
#           Ireland                                   76.000000  ...
#           Italy                                     58.600000  ...
#           Latvia                                    63.066667  ...
#           Lithuania                                 56.233333  ...
#           Luxembourg                                75.866667  ...
#           Netherlands                               82.066667  ...
#           Norway                                    90.033333  ...
#           Poland                                    67.466667  ...
#           Portugal                                  73.766667  ...
#           Russia                                    53.466667  ...
#           Slovak Republic                           63.700000  ...
#           Slovenia                                  86.166667  ...
#           Spain                                     82.166667  ...
#           Sweden                                    75.566667  ...
#           Switzerland                               85.333333  ...
#           Turkey                                    59.833333  ...
#           United Kingdom                            77.766667  ...
# NA        Canada                                    82.500000  ...
#           Mexico                                    41.966667  ...
#           United States                             73.900000  ...
# OC        Australia                                 64.133333  ...
#           New Zealand                               66.266667  ...
# OECD      OECD - Total                              68.500000  ...
# SA        Brazil                                    35.866667  ...
#           Chile                                     48.000000  ...
#           Colombia                                  44.566667  ...
#
# Unit                                                                        \
# Indicator                 Self-reported health Voter turnout Water quality
# Continent Country
# AF        South Africa                     NaN          73.0     67.000000
# AS        Israel                     86.750000          72.0     67.000000
#           Japan                      34.800000          53.0     87.000000
#           Korea                      33.000000          77.0     76.000000
# EU        Austria                    70.600000          80.0     92.000000
#           Belgium                    73.600000          89.0     83.666667
#           Czech Republic             60.800000          61.0     86.666667
#           Denmark                    72.600000          86.0     95.000000
#           Estonia                    54.400000          64.0     84.000000
#           Finland                    70.200000          67.0     95.000000
#           France                     66.400000          75.0     81.000000
#           Germany                    65.400000          76.0     91.333333
#           Greece                     76.000000          64.0     69.333333
#           Hungary                    61.000000          70.0     77.000000
#           Iceland                    76.000000          79.0     98.666667
#           Ireland                    82.800000          65.0     85.000000
#           Italy                      71.800000          73.0     71.000000
#           Latvia                     48.000000          59.0     79.333333
#           Lithuania                  45.600000          51.0     80.666667
#           Luxembourg                 69.400000          91.0     84.000000
#           Netherlands                75.800000          82.0     93.000000
#           Norway                     77.200000          78.0     97.666667
#           Poland                     60.000000          55.0     82.000000
#           Portugal                   48.200000          56.0     86.333333
#           Russia                     43.333333          68.0     55.333333
#           Slovak Republic            68.600000          60.0     84.666667
#           Slovenia                   64.400000          53.0     89.666667
#           Spain                      74.000000          70.0     72.333333
#           Sweden                     75.000000          86.0     96.000000
#           Switzerland                77.400000          49.0     95.333333
#           Turkey                     70.400000          86.0     65.000000
#           United Kingdom             70.000000          69.0     83.666667
# NA        Canada                     87.800000          68.0     91.000000
#           Mexico                     65.666667          63.0     67.666667
#           United States              86.800000          65.0     82.666667
# OC        Australia                  87.250000          91.0     92.666667
#           New Zealand                89.250000          80.0     89.000000
# OECD      OECD - Total               69.200000          68.0     81.000000
# SA        Brazil                           NaN          79.0     73.000000
#           Chile                      57.000000          47.0     71.000000
#           Colombia                         NaN          53.0     74.666667
#
# Unit                              Ratio                   \
# Indicator                 Homicide rate Rooms per person
# Continent Country
# AF        South Africa        14.000000              NaN
# AS        Israel               1.833333              1.2
#           Japan                0.200000              1.9
#           Korea                1.000000              1.5
# EU        Austria              0.466667              1.6
#           Belgium              1.033333              2.2
#           Czech Republic       0.500000              1.4
#           Denmark              0.600000              1.9
#           Estonia              3.166667              1.6
#           Finland              1.266667              1.9
#           France               0.466667              1.8
#           Germany              0.500000              1.8
#           Greece               0.833333              1.2
#           Hungary              1.000000              1.2
#           Iceland              0.500000              1.6
#           Ireland              0.666667              2.1
#           Italy                0.600000              1.4
#           Latvia               4.933333              1.2
#           Lithuania            3.433333              1.5
#           Luxembourg           0.566667              1.9
#           Netherlands          0.600000              1.9
#           Norway               0.400000              2.1
#           Poland               0.733333              1.1
#           Portugal             1.000000              1.7
#           Russia               9.933333              0.9
#           Slovak Republic      0.800000              1.1
#           Slovenia             0.600000              1.5
#           Spain                0.600000              1.9
#           Sweden               0.900000              1.7
#           Switzerland          0.600000              1.9
#           Turkey               1.366667              1.0
#           United Kingdom       0.166667              1.9
# NA        Canada               1.266667              2.6
#           Mexico              18.633333              1.0
#           United States        5.500000              2.4
# OC        Australia            1.100000              NaN
#           New Zealand          1.300000              2.4
# OECD      OECD - Total         3.733333              1.8
# SA        Brazil              27.000000              NaN
#           Chile                4.200000              1.2
#           Colombia            25.000000              1.2
#
# Unit                                                     US Dollar  \
# Indicator                 Household net adjusted disposable income
# Continent Country
# AF        South Africa                                         NaN
# AS        Israel                                               NaN
#           Japan                                            29798.0
#           Korea                                            21882.0
# EU        Austria                                          33541.0
#           Belgium                                          30364.0
#           Czech Republic                                   21453.0
#           Denmark                                          29606.0
#           Estonia                                          19697.0
#           Finland                                          29943.0
#           France                                           31304.0
#           Germany                                          34294.0
#           Greece                                           17700.0
#           Hungary                                              NaN
#           Iceland                                              NaN
#           Ireland                                          25310.0
#           Italy                                            26588.0
#           Latvia                                           16275.0
#           Lithuania                                        21660.0
#           Luxembourg                                       39264.0
#           Netherlands                                      29333.0
#           Norway                                           35725.0
#           Poland                                           19814.0
#           Portugal                                         21203.0
#           Russia                                               NaN
#           Slovak Republic                                  20474.0
#           Slovenia                                         20820.0
#           Spain                                            23999.0
#           Sweden                                           31287.0
#           Switzerland                                      37466.0
#           Turkey                                               NaN
#           United Kingdom                                   28715.0
# NA        Canada                                           30854.0
#           Mexico                                               NaN
#           United States                                    45284.0
# OC        Australia                                        32759.0
#           New Zealand                                          NaN
# OECD      OECD - Total                                     33604.0
# SA        Brazil                                               NaN
#           Chile                                                NaN
#           Colombia                                             NaN
#
# Unit                                                              \
# Indicator                 Household net wealth Personal earnings
# Continent Country
# AF        South Africa                     NaN               NaN
# AS        Israel                           NaN           35067.0
#           Japan                       305878.0           40863.0
#           Korea                       285980.0           35191.0
# EU        Austria                     308325.0           50349.0
#           Belgium                     386006.0           49675.0
#           Czech Republic                   NaN           25372.0
#           Denmark                     118637.0           51466.0
#           Estonia                     159373.0           24336.0
#           Finland                     200827.0           42964.0
#           France                      280653.0           43755.0
#           Germany                     259667.0           47585.0
#           Greece                      150134.0           26064.0
#           Hungary                     104458.0           22576.0
#           Iceland                          NaN           61787.0
#           Ireland                     217130.0           47653.0
#           Italy                       279889.0           36658.0
#           Latvia                       70160.0           23683.0
#           Lithuania                        NaN           24287.0
#           Luxembourg                  769053.0           63062.0
#           Netherlands                 157824.0           52877.0
#           Norway                      228936.0           51212.0
#           Poland                      210991.0           27046.0
#           Portugal                    232666.0           25367.0
#           Russia                           NaN               NaN
#           Slovak Republic             119696.0           24328.0
#           Slovenia                    203044.0           34933.0
#           Spain                       373548.0           38507.0
#           Sweden                           NaN           42393.0
#           Switzerland                      NaN           62283.0
#           Turkey                           NaN               NaN
#           United Kingdom              548392.0           43732.0
# NA        Canada                      423849.0           47622.0
#           Mexico                           NaN           15314.0
#           United States               632100.0           60558.0
# OC        Australia                   427064.0           49126.0
#           New Zealand                 388514.0           40043.0
# OECD      OECD - Total                408376.0           43241.0
# SA        Brazil                           NaN               NaN
#           Chile                       100967.0           25879.0
#           Colombia                         NaN               NaN
#
# Unit                                Years
# Indicator                 Life expectancy Years in education
# Continent Country
# AF        South Africa          57.500000                NaN
# AS        Israel                82.466667          15.633333
#           Japan                 84.066667          16.366667
#           Korea                 82.366667          17.266667
# EU        Austria               81.700000          17.000000
#           Belgium               81.500000          19.300000
#           Czech Republic        79.100000          17.900000
#           Denmark               80.900000          19.500000
#           Estonia               77.766667          17.700000
#           Finland               81.500000          19.833333
#           France                82.366667          16.500000
#           Germany               81.066667          18.100000
#           Greece                81.466667          19.000000
#           Hungary               76.166667          16.433333
#           Iceland               82.266667          19.033333
#           Ireland               81.766667          18.100000
#           Italy                 83.300000          16.600000
#           Latvia                74.700000          18.033333
#           Lithuania             74.800000          18.400000
#           Luxembourg            82.766667          15.100000
#           Netherlands           81.600000          18.666667
#           Norway                82.466667          18.333333
#           Poland                77.966667          17.666667
#           Portugal              81.200000          16.933333
#           Russia                71.800000          16.200000
#           Slovak Republic       77.266667          15.766667
#           Slovenia              81.266667          18.366667
#           Spain                 83.400000          17.900000
#           Sweden                82.366667          19.300000
#           Switzerland           83.666667          17.500000
#           Turkey                78.000000          18.300000
#           United Kingdom        81.200000          17.500000
# NA        Canada                81.866667          17.333333
#           Mexico                75.400000          15.166667
#           United States         78.600000          17.200000
# OC        Australia             82.500000          20.966667
#           New Zealand           81.700000          17.700000
# OECD      OECD - Total          80.200000          17.200000
# SA        Brazil                74.766667          16.166667
#           Chile                 79.900000          17.500000
#           Colombia              76.233333          14.100000
#
# [41 rows x 24 columns]

# %%
dataset_multindex.droplevel(0, axis=0).head()
# Out:
# Unit             Average score  \
# Indicator    Life satisfaction
# Country
# South Africa          4.700000
# Israel                7.225000
# Japan                 5.900000
# Korea                 5.866667
# Austria               7.225000
#
# Unit                                                                           \
# Indicator    Stakeholder engagement for developing regulations Student skills
# Country
# South Africa                                               NaN            NaN
# Israel                                                     2.5          470.0
# Japan                                                      1.4          528.8
# Korea                                                      2.9          520.0
# Austria                                                    1.3          492.8
#
# Unit                                             Hours  \
# Indicator    Time devoted to leisure and personal care
# Country
# South Africa                                 14.770000
# Israel                                             NaN
# Japan                                              NaN
# Korea                                        14.583333
# Austria                                      14.530000
#
# Unit         Micrograms per cubic metre                         Percentage  \
# Indicator                 Air pollution Dwellings without basic facilities
# Country
# South Africa                       22.0                               37.0
# Israel                             21.0                                NaN
# Japan                              14.0                                6.4
# Korea                              28.0                                2.5
# Austria                            16.0                                0.9
#
# Unit                                                                   \
# Indicator    Educational attainment Employees working very long hours
# Country
# South Africa              73.333333                         17.840000
# Israel                    87.333333                         15.273333
# Japan                           NaN                               NaN
# Korea                     87.666667                               NaN
# Austria                   85.000000                          6.590000
#
# Unit                                                              ...  \
# Indicator    Employment rate Feeling safe walking alone at night  ...
# Country                                                           ...
# South Africa       43.333333                           36.333333  ...
# Israel             69.000000                           69.966667  ...
# Japan              75.000000                           72.800000  ...
# Korea              66.666667                           66.666667  ...
# Austria            72.000000                           80.700000  ...
#
# Unit                                                                  Ratio  \
# Indicator    Self-reported health Voter turnout Water quality Homicide rate
# Country
# South Africa                  NaN          73.0          67.0     14.000000
# Israel                      86.75          72.0          67.0      1.833333
# Japan                       34.80          53.0          87.0      0.200000
# Korea                       33.00          77.0          76.0      1.000000
# Austria                     70.60          80.0          92.0      0.466667
#
# Unit                                                         US Dollar  \
# Indicator    Rooms per person Household net adjusted disposable income
# Country
# South Africa              NaN                                      NaN
# Israel                    1.2                                      NaN
# Japan                     1.9                                  29798.0
# Korea                     1.5                                  21882.0
# Austria                   1.6                                  33541.0
#
# Unit                                                          Years  \
# Indicator    Household net wealth Personal earnings Life expectancy
# Country
# South Africa                  NaN               NaN       57.500000
# Israel                        NaN           35067.0       82.466667
# Japan                    305878.0           40863.0       84.066667
# Korea                    285980.0           35191.0       82.366667
# Austria                  308325.0           50349.0       81.700000
#
# Unit
# Indicator    Years in education
# Country
# South Africa                NaN
# Israel                15.633333
# Japan                 16.366667
# Korea                 17.266667
# Austria               17.000000
#
# [5 rows x 24 columns]

# %%
dataset_multindex.droplevel(1, axis=0).head()
# Out:
# Unit          Average score                                                    \
# Indicator Life satisfaction Stakeholder engagement for developing regulations
# Continent
# AF                 4.700000                                               NaN
# AS                 7.225000                                               2.5
# AS                 5.900000                                               1.4
# AS                 5.866667                                               2.9
# EU                 7.225000                                               1.3
#
# Unit                                                         Hours  \
# Indicator Student skills Time devoted to leisure and personal care
# Continent
# AF                   NaN                                 14.770000
# AS                 470.0                                       NaN
# AS                 528.8                                       NaN
# AS                 520.0                                 14.583333
# EU                 492.8                                 14.530000
#
# Unit      Micrograms per cubic metre                         Percentage  \
# Indicator              Air pollution Dwellings without basic facilities
# Continent
# AF                              22.0                               37.0
# AS                              21.0                                NaN
# AS                              14.0                                6.4
# AS                              28.0                                2.5
# EU                              16.0                                0.9
#
# Unit                                                                \
# Indicator Educational attainment Employees working very long hours
# Continent
# AF                     73.333333                         17.840000
# AS                     87.333333                         15.273333
# AS                           NaN                               NaN
# AS                     87.666667                               NaN
# EU                     85.000000                          6.590000
#
# Unit                                                           ...  \
# Indicator Employment rate Feeling safe walking alone at night  ...
# Continent                                                      ...
# AF              43.333333                           36.333333  ...
# AS              69.000000                           69.966667  ...
# AS              75.000000                           72.800000  ...
# AS              66.666667                           66.666667  ...
# EU              72.000000                           80.700000  ...
#
# Unit                                                               Ratio  \
# Indicator Self-reported health Voter turnout Water quality Homicide rate
# Continent
# AF                         NaN          73.0          67.0     14.000000
# AS                       86.75          72.0          67.0      1.833333
# AS                       34.80          53.0          87.0      0.200000
# AS                       33.00          77.0          76.0      1.000000
# EU                       70.60          80.0          92.0      0.466667
#
# Unit                                                      US Dollar  \
# Indicator Rooms per person Household net adjusted disposable income
# Continent
# AF                     NaN                                      NaN
# AS                     1.2                                      NaN
# AS                     1.9                                  29798.0
# AS                     1.5                                  21882.0
# EU                     1.6                                  33541.0
#
# Unit                                                       Years  \
# Indicator Household net wealth Personal earnings Life expectancy
# Continent
# AF                         NaN               NaN       57.500000
# AS                         NaN           35067.0       82.466667
# AS                    305878.0           40863.0       84.066667
# AS                    285980.0           35191.0       82.366667
# EU                    308325.0           50349.0       81.700000
#
# Unit
# Indicator Years in education
# Continent
# AF                       NaN
# AS                 15.633333
# AS                 16.366667
# AS                 17.266667
# EU                 17.000000
#
# [5 rows x 24 columns]

# %%
dataset_multindex.droplevel(0, axis=1).head()

# %% [markdown]
# Noten que estos métodos generan DataFrames nuevos. Por ende, al ejecutarse deben reemplazar los `DataFrames` originales.

# %% [markdown]
# ---
#
# ## 4.- Fundir / Melt
#
# El proceso inverso al pivoteado:

# %% [markdown]
# ![Melt](https://i.ibb.co/Y7x8XMz/melt.png)

# %% [markdown]
# En este caso retornaremos a algo similar al formato original del dataset:

# %%
dataset.head()

# %%
dataset.reset_index(drop=True).melt(id_vars=["Country"])
# Out:
#              Country               variable         value
# 0          Australia          Air pollution      5.000000
# 1            Austria          Air pollution     16.000000
# 2            Belgium          Air pollution     15.000000
# 3             Brazil          Air pollution     10.000000
# 4             Canada          Air pollution      7.000000
# ...              ...                    ...           ...
# 1020          Sweden  GPD per capita (2018)  54589.060390
# 1021     Switzerland  GPD per capita (2018)  82818.108160
# 1022          Turkey  GPD per capita (2018)   9370.176355
# 1023  United Kingdom  GPD per capita (2018)  43043.227820
# 1024   United States  GPD per capita (2018)  62996.664820
#
# [1025 rows x 3 columns]

# %% [markdown]
# ---
#
# ## 5.- Agregaciones con Group By
#
#
# ![Group By](https://i.ibb.co/G0yHWsC/group-by.png)
#
# **Group by** es un proceso que implica uno o más de los siguientes pasos:
#
#
# - **Separar** los datos bajo algún criterio o grupo.
#
# - **Aplicar** esta función a estos datos agrupados.
#
# - **Combinar** los resultados en un nuevo `DataFrame`.
#
#
# Comunmente deseamos hacer alguna operación sobre los datos agrupados.
#
# - **Agregar**: Calcular alguna métrica o estadístico por grupo.
#
#     - Tamaño/Conteo.
#     - Promedio/Desviación Estandar.
#
#
# - **Transformar**: Hacer transformaciones por grupo (Propuesto).
#
#     - Estandarizar datos.
#     - Rellenar NaN's con promedios, etc...
#
#
# - **Filtrar**: Descartar algunos grupos según algún criterio (Propuesto).

# %% [markdown]
# ### Dataset de Temperaturas Globales
#
# ![wbg_climate](https://i.ibb.co/Vwcb0SF/wbg-climate.png)
#
#
# https://climateknowledgeportal.worldbank.org/download-data

# %% [markdown]
# **Cargar Dataset de Temperaturas Globales**

# %%
temperaturas = pd.read_csv("https://raw.githubusercontent.com/maranedah/MDS7202/main/clases/Clase%208%20-%20Pandas%20-%20Parte%20II/resources/temperature.csv")
temperaturas.head(20)
# Out:
#     Temperature  Year Month      Country ISO3
# 0      -0.03110  1991   Jan  Afghanistan  AFG
# 1       1.43654  1991   Feb  Afghanistan  AFG
# 2       6.88685  1991   Mar  Afghanistan  AFG
# 3      12.93970  1991   Apr  Afghanistan  AFG
# 4      17.07550  1991   May  Afghanistan  AFG
# 5      23.07770  1991   Jun  Afghanistan  AFG
# 6      25.57100  1991   Jul  Afghanistan  AFG
# 7      23.96730  1991   Aug  Afghanistan  AFG
# 8      19.38000  1991   Sep  Afghanistan  AFG
# 9      12.87790  1991   Oct  Afghanistan  AFG
# 10      7.31675  1991   Nov  Afghanistan  AFG
# 11      4.23571  1991   Dec  Afghanistan  AFG
# 12      0.74637  1992   Jan  Afghanistan  AFG
# 13      2.46018  1992   Feb  Afghanistan  AFG
# 14      5.71341  1992   Mar  Afghanistan  AFG
# 15     11.69260  1992   Apr  Afghanistan  AFG
# 16     16.11080  1992   May  Afghanistan  AFG
# 17     22.88750  1992   Jun  Afghanistan  AFG
# 18     24.70680  1992   Jul  Afghanistan  AFG
# 19     22.86330  1992   Aug  Afghanistan  AFG

# %%
temperaturas.columns
# Out:
# Index(['Temperature', 'Year', 'Month', 'Country', 'ISO3'], dtype='object')

# %% [markdown]
# **Filtrar solo los de Chile**

# %%
temperaturas["Country"] == "Chile"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 59899    False
# 59900    False
# 59901    False
# 59902    False
# 59903    False
# Name: Country, Length: 59904, dtype: bool

# %%
t_chile = temperaturas[temperaturas["Country"] == "Chile"]
t_chile
# Out:
#        Temperature  Year Month Country ISO3
# 10608     12.53860  1991   Jan   Chile  CHL
# 10609     12.29140  1991   Feb   Chile  CHL
# 10610     11.13730  1991   Mar   Chile  CHL
# 10611      8.85700  1991   Apr   Chile  CHL
# 10612      6.70605  1991   May   Chile  CHL
# ...            ...   ...   ...     ...  ...
# 10915      5.83910  2016   Aug   Chile  CHL
# 10916      7.19059  2016   Sep   Chile  CHL
# 10917      8.81492  2016   Oct   Chile  CHL
# 10918     10.71450  2016   Nov   Chile  CHL
# 10919     12.39610  2016   Dec   Chile  CHL
#
# [312 rows x 5 columns]

# %%
import plotly.express as px

px.line(t_chile, x="Month", y="Temperature", color="Year", height=600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="84ece96e-3d20-42e5-b053-e7233b578a06" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84ece96e-3d20-42e5-b053-e7233b578a06")) {                    Plotly.newPlot(                        "84ece96e-3d20-42e5-b053-e7233b578a06",                        [{"hovertemplate":"Year=1991<br>Month=%{x}<br>Temperature=%{y}<extra></extra>","legendgroup":"1991","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"1991","orientation":"v","showlegend":true,"x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[12.5386,12.2914,11.1373,8.857,6.70605,4.64511,3.67834,4.05806,6.6008,7.41883,9.96322,10.2007],"yaxis":"y","type":"scatter"},{"hovertemplate":"Year=1992<br>Month=%{x}<br>Temperature=%{y}<extra></extra>","legendgroup":"1992","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"1992","orientation":"v","showlegend":true,"x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[13.3536,11.4709,11.5469,8.61049,5.52874,3.8424,2.52941,5.00639,6.15123,7.75703,10.0407,11.7555],"yaxis":"y","type":"scatter"},{"hovertemplate":"Year=1993<br>Month=%{x}<br>Temperature=%{y}<extra></extra>","legendgroup":"1993","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"1993","orientation":"v","showlegend":true,"x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[12.5437,12.5439,11.6593,8.37375,5.81204,4.22072,3.92746,5.56384,6.43839,8.55355,9.88435,11.6997],"yaxis":"y","type":"scatter"},{"hovertemplate":"Year=1994<br>Month=%{x}<br>Temperature=%{y}<extra></extra>","legendgroup":"1994","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"1994","orientation":"v","showlegend":true,"x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[13.1871,11.6278,11.2772,8.52128,6.67252,5.23361,3.69367,5.16521,6.75231,8.11482,10.353,12.4018],"yaxis":"y","type":"scatter"},{"hovertemplate":"Year=1995<br>Month=%{x}<br>Temperature=%{y}<extra></extra>","legendgroup":"1995","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"1995","orientation":"v","showlegend":true,"x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[12.3385,11.8478,10.6367,9.11017,6.80263,4.16912,2.62724,3.64301,6.32269,8.33436,10.4544,13.2743],"yaxis":"y","type":"scatter"},{"hovertemplate":"Year=1996<br>Month=%{x}<br>Temperature=%{y}<extra></extra>","legendgroup":"1996","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"1996","orientation":"v","showlegend":true,"x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[11.9359,11.5699,11.2592,7.99297,7.1989,3.54486,4.34828,5.411,6.91179,8.49536,10.2281,11.6474],"yaxis":"y","type":"scatter"},{"hovertemplate":"Year=1997<br>Month=%{x}<br>Temperature=%{y}<extra></extra>","legendgroup":"1997","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"1997","orientation":"v","showlegend":true,"x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[12.7446,11.1575,11.6088,9.48273,6.90652,4.84893,4.80792,5.09215,6.72262,7.99191,10.1829,11.9714],"yaxis":"y","type":"scatter"},{"hovertemplate":"Year=1998<br>Month=%{x}<br>Temperature=%{y}<extra></extra>","legendgroup":"1998","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"1998","orientation":"v","showlegend":true,"x":["Jan","Feb","Mar","Apr ...

# %%
fig = px.violin(t_chile, x="Month", y="Temperature")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="04d50e60-c846-4c18-891e-735e8020f8c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04d50e60-c846-4c18-891e-735e8020f8c0")) {                    Plotly.newPlot(                        "04d50e60-c846-4c18-891e-735e8020f8c0",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Month=%{x}<br>Temperature=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","offsetgroup":"","orientation":"v","scalegroup":"True","showlegend":false,"x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"x0":" ","xaxis":"x","y":[12.5386,12.2914,11.1373,8.857,6.70605,4.64511,3.67834,4.05806,6.6008,7.41883,9.96322,10.2007,13.3536,11.4709,11.5469,8.61049,5.52874,3.8424,2.52941,5.00639,6.15123,7.75703,10.0407,11.7555,12.5437,12.5439,11.6593,8.37375,5.81204,4.22072,3.92746,5.56384,6.43839,8.55355,9.88435,11.6997,13.1871,11.6278,11.2772,8.52128,6.67252,5.23361,3.69367,5.16521,6.75231,8.11482,10.353,12.4018,12.3385,11.8478,10.6367,9.11017,6.80263,4.16912,2.62724,3.64301,6.32269,8.33436,10.4544,13.2743,11.9359,11.5699,11.2592,7.99297,7.1989,3.54486,4.34828,5.411,6.91179,8.49536,10.2281,11.6474,12.7446,11.1575,11.6088,9.48273,6.90652,4.84893,4.80792,5.09215,6.72262,7.99191,10.1829,11.9714,12.7396,12.7452,11.1204,9.02652,7.43721,5.62819,5.82987,5.45415,5.71679,8.84985,10.1932,12.1056,12.8157,12.7409,10.7313,8.12245,6.31238,3.63432,3.65039,5.12151,6.7544,8.70829,10.3294,11.5597,12.5468,11.5821,10.1331,8.84131,6.06873,4.23204,3.04342,4.71347,5.11566,8.21364,9.19119,11.2468,12.3213,12.5583,10.4876,8.20538,5.65842,4.54218,3.11327,5.0987,6.1623,8.7834,9.3059,12.4921,12.5696,12.5262,10.2428,8.17758,5.7096,2.61044,4.23134,5.02827,6.59307,7.94863,9.51981,11.7107,12.5883,12.2284,11.3923,8.19428,6.78527,5.27374,4.68253,4.87477,6.76552,8.59073,10.3428,11.0236,13.5758,13.0926,11.8772,8.81913,5.33228,5.59596,4.06347,5.13585,6.93902, ...

# %% [markdown]
# ### Paso 1: Separar
#
# En esta parte veremos el primer paso del group-by: **Separar** por grupos.
#
#
# ![Group By](https://i.ibb.co/G0yHWsC/group-by.png)

# %% [markdown]
# Para esto, agrupamos temperaturas de Chile por mes:

# %% [markdown]
# #### Cantidad de Grupos

# %%
t_chile.head(10)
# Out:
#        Temperature  Year Month Country ISO3
# 10608     12.53860  1991   Jan   Chile  CHL
# 10609     12.29140  1991   Feb   Chile  CHL
# 10610     11.13730  1991   Mar   Chile  CHL
# 10611      8.85700  1991   Apr   Chile  CHL
# 10612      6.70605  1991   May   Chile  CHL
# 10613      4.64511  1991   Jun   Chile  CHL
# 10614      3.67834  1991   Jul   Chile  CHL
# 10615      4.05806  1991   Aug   Chile  CHL
# 10616      6.60080  1991   Sep   Chile  CHL
# 10617      7.41883  1991   Oct   Chile  CHL

# %%
t_chile.groupby("Month")

# %%
len(t_chile.groupby("Month"))
# Out:
# 12

# %% [markdown]
# #### Obtener el Listado de Grupos que Generó

# %%
import pprint

pprint.pprint(t_chile.groupby("Month").groups)
# Out:
# {'Apr': Int64Index([10611, 10623, 10635, 10647, 10659, 10671, 10683, 10695, 10707,
#             10719, 10731, 10743, 10755, 10767, 10779, 10791, 10803, 10815,
#             10827, 10839, 10851, 10863, 10875, 10887, 10899, 10911],
#            dtype='int64'),
#  'Aug': Int64Index([10615, 10627, 10639, 10651, 10663, 10675, 10687, 10699, 10711,
#             10723, 10735, 10747, 10759, 10771, 10783, 10795, 10807, 10819,
#             10831, 10843, 10855, 10867, 10879, 10891, 10903, 10915],
#            dtype='int64'),
#  'Dec': Int64Index([10619, 10631, 10643, 10655, 10667, 10679, 10691, 10703, 10715,
#             10727, 10739, 10751, 10763, 10775, 10787, 10799, 10811, 10823,
#             10835, 10847, 10859, 10871, 10883, 10895, 10907, 10919],
#            dtype='int64'),
#  'Feb': Int64Index([10609, 10621, 10633, 10645, 10657, 10669, 10681, 10693, 10705,
#             10717, 10729, 10741, 10753, 10765, 10777, 10789, 10801, 10813,
#             10825, 10837, 10849, 10861, 10873, 10885, 10897, 10909],
#            dtype='int64'),
#  'Jan': Int64Index([10608, 10620, 10632, 10644, 10656, 10668, 10680, 10692, 10704,
#             10716, 10728, 10740, 10752, 10764, 10776, 10788, 10800, 10812,
#             10824, 10836, 10848, 10860, 10872, 10884, 10896, 10908],
#            dtype='int64'),
#  'Jul': Int64Index([10614, 10626, 10638, 10650, 10662, 10674, 10686, 10698, 10710,
#             10722, 10734, 10746, 10758, 10770, 10782, 10794, 10806, 10818,
#             10830, 10842, 10854, 10866, 10878, 10890, 10902, 10914],
#            dtype='int64'),
#  'Jun': Int64Index([10613, 10625, 10637, 10649, 10661, 10673, 10685, 10697, 10709,
#             10721, 10733, 10745, 10757, 10769, 10781, 10793, 10805, 10817,
#             10829, 10841, 10853, 10865, 10877, 10889, 10901, 10913],
#            dtype='int64'),
#  'Mar': Int64Index([10610, 10622, 10634, 10646, 10658, 10670, 10682, 10694, 10706,
#             10718, 10730, 10742, 10754, 10766, 10778, 10790, 10802, 10814,
#             10826, 10838, 10850, 10862, 10874, 10886, 10898, 10910],
#            dtype='int64'),
#  'May': Int64Index([10612, 10624, 10636, 10648, 10660, 10672, 10684, 10696, 10708,
#             10720, 10732, 10744, 10756, 10768, 10780, 10792, 10804, 10816,
#             10828, 10840, 10852, 10864, 10876, 10888, 10900, 10912],
#            dtype='int64'),
#  'Nov': Int64Index([10618, 10630, 10642, 10654, 10666, 10678, 10690, 10702, 10714,
#             10726, 10738, 10750, 10762, 10774, 10786, 10798, 10810, 10822,
#             10834, 10846, 10858, 10870, 10882, 10894, 10906, 10918],
#            dtype='int64'),
#  'Oct': Int64Index([10617, 10629, 10641, 10653, 10665, 10677, 10689, 10701, 10713,
#             10725, 10737, 10749, 10761, 10773, 10785, 10797, 10809, 10821,
#             10833, 10845, 10857, 10869, 10881, 10893, 10905, 10917],
#            dtype='int64'),
#  'Sep': Int64Index([10616, 10628, 10640, 10652, 10664, 10676, 10688, 10700, 10712,
#             10724, 10736, 10748, 10760, 10772, 10784, 10796, 10808, 10820,
#             10832, 10844, 10856, 10868, 10880, 10892, 10904, 10916],
#            dtype='int64')}

# %%
t_chile.loc[
    [
        10611,
        10623,
        10635,
        10647,
        10659,
        10671,
        10683,
        10695,
        10707,
        10719,
        10731,
        10743,
        10755,
        10767,
        10779,
        10791,
        10803,
        10815,
        10827,
        10839,
        10851,
        10863,
        10875,
        10887,
        10899,
        10911,
    ]
]
# Out:
#        Temperature  Year Month Country ISO3
# 10611      8.85700  1991   Apr   Chile  CHL
# 10623      8.61049  1992   Apr   Chile  CHL
# 10635      8.37375  1993   Apr   Chile  CHL
# 10647      8.52128  1994   Apr   Chile  CHL
# 10659      9.11017  1995   Apr   Chile  CHL
# 10671      7.99297  1996   Apr   Chile  CHL
# 10683      9.48273  1997   Apr   Chile  CHL
# 10695      9.02652  1998   Apr   Chile  CHL
# 10707      8.12245  1999   Apr   Chile  CHL
# 10719      8.84131  2000   Apr   Chile  CHL
# 10731      8.20538  2001   Apr   Chile  CHL
# 10743      8.17758  2002   Apr   Chile  CHL
# 10755      8.19428  2003   Apr   Chile  CHL
# 10767      8.81913  2004   Apr   Chile  CHL
# 10779      7.95617  2005   Apr   Chile  CHL
# 10791      8.65331  2006   Apr   Chile  CHL
# 10803      8.54072  2007   Apr   Chile  CHL
# 10815      8.12552  2008   Apr   Chile  CHL
# 10827      9.81651  2009   Apr   Chile  CHL
# 10839      8.37247  2010   Apr   Chile  CHL
# 10851      8.64091  2011   Apr   Chile  CHL
# 10863      8.48071  2012   Apr   Chile  CHL
# 10875      9.52546  2013   Apr   Chile  CHL
# 10887      8.30812  2014   Apr   Chile  CHL
# 10899      9.87860  2015   Apr   Chile  CHL
# 10911      7.82234  2016   Apr   Chile  CHL

# %% [markdown]
# #### Obtener algún grupo en particular

# %%
t_chile.groupby("Month").get_group("Apr")
# Out:
#        Temperature  Year Month Country ISO3
# 10611      8.85700  1991   Apr   Chile  CHL
# 10623      8.61049  1992   Apr   Chile  CHL
# 10635      8.37375  1993   Apr   Chile  CHL
# 10647      8.52128  1994   Apr   Chile  CHL
# 10659      9.11017  1995   Apr   Chile  CHL
# 10671      7.99297  1996   Apr   Chile  CHL
# 10683      9.48273  1997   Apr   Chile  CHL
# 10695      9.02652  1998   Apr   Chile  CHL
# 10707      8.12245  1999   Apr   Chile  CHL
# 10719      8.84131  2000   Apr   Chile  CHL
# 10731      8.20538  2001   Apr   Chile  CHL
# 10743      8.17758  2002   Apr   Chile  CHL
# 10755      8.19428  2003   Apr   Chile  CHL
# 10767      8.81913  2004   Apr   Chile  CHL
# 10779      7.95617  2005   Apr   Chile  CHL
# 10791      8.65331  2006   Apr   Chile  CHL
# 10803      8.54072  2007   Apr   Chile  CHL
# 10815      8.12552  2008   Apr   Chile  CHL
# 10827      9.81651  2009   Apr   Chile  CHL
# 10839      8.37247  2010   Apr   Chile  CHL
# 10851      8.64091  2011   Apr   Chile  CHL
# 10863      8.48071  2012   Apr   Chile  CHL
# 10875      9.52546  2013   Apr   Chile  CHL
# 10887      8.30812  2014   Apr   Chile  CHL
# 10899      9.87860  2015   Apr   Chile  CHL
# 10911      7.82234  2016   Apr   Chile  CHL

# %% [markdown]
# ### Paso 2: Aplicar
#
# En este paso veremos las distintas opciones que tenemos en el paso **aplicar**: agregar, transformar o filtrar.
#
# ![Group By](https://i.ibb.co/G0yHWsC/group-by.png)

# %% [markdown]
# #### Agregar
#
# Una de estas opciones son las funciones de agregación: operaciones que cuentan o obtienen estadísticos a cerca de cada grupo.
#
# Algunas funciones de agregación built-in de pandas son:
# <div align='center'>
# <img src="./resources/aggregations.png" alt="Agregaciones" width=500px/>
# </div>

# %% [markdown]
# ##### Tamaño

# %%
t_chile.groupby("Month").size()
# Out:
# Month
# Apr    26
# Aug    26
# Dec    26
# Feb    26
# Jan    26
# Jul    26
# Jun    26
# Mar    26
# May    26
# Nov    26
# Oct    26
# Sep    26
# dtype: int64

# %% [markdown]
# ##### Promedio
#
# **Por  Mes**

# %%
t_chile
# Out:
#        Temperature  Year Month Country ISO3
# 10608     12.53860  1991   Jan   Chile  CHL
# 10609     12.29140  1991   Feb   Chile  CHL
# 10610     11.13730  1991   Mar   Chile  CHL
# 10611      8.85700  1991   Apr   Chile  CHL
# 10612      6.70605  1991   May   Chile  CHL
# ...            ...   ...   ...     ...  ...
# 10915      5.83910  2016   Aug   Chile  CHL
# 10916      7.19059  2016   Sep   Chile  CHL
# 10917      8.81492  2016   Oct   Chile  CHL
# 10918     10.71450  2016   Nov   Chile  CHL
# 10919     12.39610  2016   Dec   Chile  CHL
#
# [312 rows x 5 columns]

# %%
t_chile_prom_mes = t_chile.groupby("Month").mean()
t_chile_prom_mes
# Out:
#        Temperature    Year
# Month
# Apr       8.632918  2003.5
# Aug       4.874367  2003.5
# Dec      11.862162  2003.5
# Feb      12.331531  2003.5
# Jan      12.890127  2003.5
# Jul       3.990776  2003.5
# Jun       4.566924  2003.5
# Mar      11.175054  2003.5
# May       6.305406  2003.5
# Nov      10.031982  2003.5
# Oct       8.313173  2003.5
# Sep       6.479313  2003.5

# %%
# Arreglo de conveniencia para ordenar los resultados por mes.
MESES = [
    "Jan",
    "Feb",
    "Mar",
    "Apr",
    "May",
    "Jun",
    "Jul",
    "Aug",
    "Sep",
    "Oct",
    "Nov",
    "Dec",
]

t_chile_prom_mes = t_chile.groupby("Month").mean()
t_chile_prom_mes = t_chile_prom_mes.loc[MESES]

t_chile_prom_mes
# Out:
#        Temperature    Year
# Month
# Jan      12.890127  2003.5
# Feb      12.331531  2003.5
# Mar      11.175054  2003.5
# Apr       8.632918  2003.5
# May       6.305406  2003.5
# Jun       4.566924  2003.5
# Jul       3.990776  2003.5
# Aug       4.874367  2003.5
# Sep       6.479313  2003.5
# Oct       8.313173  2003.5
# Nov      10.031982  2003.5
# Dec      11.862162  2003.5

# %%
px.line(
    t_chile_prom_mes["Temperature"],
    title="Temperatura Promedio en Chile por Mes",
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4de4976b-cf19-48ad-be95-cc1e7a947f44" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4de4976b-cf19-48ad-be95-cc1e7a947f44")) {                    Plotly.newPlot(                        "4de4976b-cf19-48ad-be95-cc1e7a947f44",                        [{"hovertemplate":"variable=Temperature<br>Month=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Temperature","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Temperature","orientation":"v","showlegend":true,"x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[12.890126923076924,12.331530769230769,11.175053846153846,8.632918461538463,6.305406153846154,4.566924230769231,3.990776153846154,4.874366538461539,6.479313076923077,8.313173076923077,10.031981538461539,11.862161538461539],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"typ ...

# %%
t_chile
# Out:
#        Temperature  Year Month Country ISO3
# 10608     12.53860  1991   Jan   Chile  CHL
# 10609     12.29140  1991   Feb   Chile  CHL
# 10610     11.13730  1991   Mar   Chile  CHL
# 10611      8.85700  1991   Apr   Chile  CHL
# 10612      6.70605  1991   May   Chile  CHL
# ...            ...   ...   ...     ...  ...
# 10915      5.83910  2016   Aug   Chile  CHL
# 10916      7.19059  2016   Sep   Chile  CHL
# 10917      8.81492  2016   Oct   Chile  CHL
# 10918     10.71450  2016   Nov   Chile  CHL
# 10919     12.39610  2016   Dec   Chile  CHL
#
# [312 rows x 5 columns]

# %% [markdown]
# > Ejercicio: Agrupar por lustros y ver como se mueve la media.

# %% [markdown]
# **Por Año**

# %%
t_chile_prom_año = t_chile.groupby("Year").mean()
t_chile_prom_año
# Out:
#       Temperature
# Year
# 1991     8.174618
# 1992     8.132774
# 1993     8.435058
# 1994     8.583360
# 1995     8.296743
# 1996     8.378638
# 1997     8.626498
# 1998     8.903882
# 1999     8.373395
# 2000     7.910688
# 2001     8.227404
# 2002     8.072337
# 2003     8.561853
# 2004     8.775460
# 2005     8.271038
# 2006     8.648243
# 2007     7.908262
# 2008     8.683983
# 2009     8.509471
# 2010     8.187509
# 2011     8.494979
# 2012     8.631189
# 2013     8.723325
# 2014     8.548038
# 2015     8.821257
# 2016     8.936417

# %%
px.line(
    t_chile_prom_año,
    title="Temperatura Promedio en Chile por Año",
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0cb7a3b3-5fe4-4b83-82d3-91117d1aab16" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0cb7a3b3-5fe4-4b83-82d3-91117d1aab16")) {                    Plotly.newPlot(                        "0cb7a3b3-5fe4-4b83-82d3-91117d1aab16",                        [{"hovertemplate":"variable=Temperature<br>Year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Temperature","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Temperature","orientation":"v","showlegend":true,"x":[1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016],"xaxis":"x","y":[8.1746175,8.132774166666666,8.435058333333332,8.58336,8.296743333333334,8.378638333333333,8.626498333333332,8.903881666666667,8.373395,7.910688333333333,8.227404166666666,8.072336666666667,8.561853333333334,8.77546,8.2710375,8.648243333333333,7.908261666666667,8.6839825,8.509470833333333,8.187509166666667,8.494979166666667,8.631189166666667,8.723325,8.548038333333333,8.8212575,8.936416666666666],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd ...

# %% [markdown]
# #### Describe
#
# Por mes:

# %%
t_chile.describe()
# Out:
#        Temperature         Year
# count   312.000000   312.000000
# mean      8.454478  2003.500000
# std       3.126838     7.512048
# min       2.529410  1991.000000
# 25%       5.569280  1997.000000
# 50%       8.488035  2003.500000
# 75%      11.543375  2010.000000
# max      13.929600  2016.000000

# %%
chile_t_stats = t_chile.groupby("Month").describe()["Temperature"]
chile_t_stats = chile_t_stats.loc[MESES]
chile_t_stats
# Out:
#        count       mean       std       min        25%        50%        75%  \
# Month
# Jan     26.0  12.890127  0.489691  11.93590  12.552500  12.747900  13.157900
# Feb     26.0  12.331531  0.634695  11.15750  11.855550  12.459100  12.744125
# Mar     26.0  11.175054  0.583369  10.13310  10.753150  11.198250  11.646675
# Apr     26.0   8.632918  0.561895   7.82234   8.197055   8.531000   8.853077
# May     26.0   6.305406  0.658122   4.75968   5.735210   6.363575   6.760283
# Jun     26.0   4.566924  0.731938   2.61044   4.182020   4.681900   5.105257
# Jul     26.0   3.990776  0.782743   2.52941   3.643715   3.995465   4.568388
# Aug     26.0   4.874367  0.694196   3.25353   4.381372   5.060210   5.360117
# Sep     26.0   6.479313  0.492104   5.11566   6.202398   6.596555   6.762740
# Oct     26.0   8.313173  0.443089   7.41883   8.022638   8.346980   8.678900
# Nov     26.0  10.031982  0.487848   8.91301   9.827340  10.085450  10.339450
# Dec     26.0  11.862162  0.669272  10.20070  11.546575  11.749950  12.355850
#
#             max
# Month
# Jan    13.92960
# Feb    13.63310
# Mar    12.18950
# Apr     9.87860
# May     7.43721
# Jun     5.62819
# Jul     5.82987
# Aug     6.08457
# Sep     7.26955
# Oct     9.11434
# Nov    10.93300
# Dec    13.27430

# %%
px.line(
    chile_t_stats.reset_index(),
    x="Month",
    y="mean",
    error_y="std",
    title="Temperatura por Mes",
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8235ff97-5b34-407b-b61f-1ba58bb17125" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8235ff97-5b34-407b-b61f-1ba58bb17125")) {                    Plotly.newPlot(                        "8235ff97-5b34-407b-b61f-1ba58bb17125",                        [{"error_y":{"array":[0.48969071100660444,0.6346950573428032,0.5833685642752919,0.5618951398450946,0.6581224468992191,0.7319380820051546,0.7827429846843825,0.6941959960353693,0.4921037991137173,0.44308868504415,0.48784771900823565,0.669271554499023]},"hovertemplate":"Month=%{x}<br>mean=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[12.890126923076922,12.331530769230769,11.175053846153846,8.632918461538463,6.305406153846154,4.566924230769231,3.9907761538461535,4.874366538461539,6.479313076923078,8.313173076923077,10.031981538461539,11.862161538461537],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d ...

# %% [markdown]
# #### Usar como filtro
#
# Exactamente igual a `temperaturas[temperaturas['Country'] == 'Chile']`

# %%
temperaturas.head(10)
# Out:
#    Temperature  Year Month      Country ISO3
# 0     -0.03110  1991   Jan  Afghanistan  AFG
# 1      1.43654  1991   Feb  Afghanistan  AFG
# 2      6.88685  1991   Mar  Afghanistan  AFG
# 3     12.93970  1991   Apr  Afghanistan  AFG
# 4     17.07550  1991   May  Afghanistan  AFG
# 5     23.07770  1991   Jun  Afghanistan  AFG
# 6     25.57100  1991   Jul  Afghanistan  AFG
# 7     23.96730  1991   Aug  Afghanistan  AFG
# 8     19.38000  1991   Sep  Afghanistan  AFG
# 9     12.87790  1991   Oct  Afghanistan  AFG

# %%
temperaturas["Country"] == "Chile"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 59899    False
# 59900    False
# 59901    False
# 59902    False
# 59903    False
# Name: Country, Length: 59904, dtype: bool

# %%
temperaturas[temperaturas["Country"] == "Chile"].head(3)
# Out:
#        Temperature  Year Month Country ISO3
# 10608      12.5386  1991   Jan   Chile  CHL
# 10609      12.2914  1991   Feb   Chile  CHL
# 10610      11.1373  1991   Mar   Chile  CHL

# %%
temperaturas.groupby(["Country"]).get_group("Chile")
# Out:
#        Temperature  Year Month Country ISO3
# 10608     12.53860  1991   Jan   Chile  CHL
# 10609     12.29140  1991   Feb   Chile  CHL
# 10610     11.13730  1991   Mar   Chile  CHL
# 10611      8.85700  1991   Apr   Chile  CHL
# 10612      6.70605  1991   May   Chile  CHL
# ...            ...   ...   ...     ...  ...
# 10915      5.83910  2016   Aug   Chile  CHL
# 10916      7.19059  2016   Sep   Chile  CHL
# 10917      8.81492  2016   Oct   Chile  CHL
# 10918     10.71450  2016   Nov   Chile  CHL
# 10919     12.39610  2016   Dec   Chile  CHL
#
# [312 rows x 5 columns]

# %% [markdown]
# #### Multi-indice
#
# También podemos ejecutar la agregación sobre varias columnas. Esto generará un DataFrame multi-indice.

# %%
stats_general = temperaturas.groupby(["Country", "Year"]).describe()

# %%
stats_general
# Out:
#                  Temperature                                            \
#                        count       mean       std       min        25%
# Country     Year
# Afghanistan 1991        12.0  12.894488  8.980163  -0.03110   6.224065
#             1992        12.0  12.544548  8.386016   0.74637   5.404147
#             1993        12.0  12.977138  8.719243  -0.08350   5.673917
#             1994        12.0  13.080018  8.875672   1.11415   7.360107
#             1995        12.0  13.040895  9.092189   0.92358   5.517030
# ...                      ...        ...       ...       ...        ...
# Venezuela   2012        12.0  25.764883  0.374583  25.21710  25.501125
#             2013        12.0  25.922492  0.553798  25.29310  25.465375
#             2014        12.0  26.028775  0.477228  25.39520  25.724875
#             2015        12.0  26.438175  0.430423  25.63690  26.114800
#             2016        12.0  26.478200  0.474389  25.84420  26.120150
#
#
#                        50%        75%      max
# Country     Year
# Afghanistan 1991  12.90880  20.304425  25.5710
#             1992  12.19535  19.109925  24.7068
#             1993  12.70540  20.447725  24.6320
#             1994  12.24925  19.975575  25.0045
#             1995  12.90710  20.140400  25.7798
# ...                    ...        ...      ...
# Venezuela   2012  25.72885  26.049450  26.4330
#             2013  25.93485  26.091300  27.1409
#             2014  25.87900  26.356625  26.9757
#             2015  26.50315  26.729575  27.0908
#             2016  26.41585  26.755900  27.3357
#
# [4992 rows x 8 columns]

# %%
temperature_stats_general = stats_general["Temperature"]

# %%
px.line(
    temperature_stats_general.reset_index(),
    x="Year",
    y="mean",
    color="Country",
    height=800,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e05da31e-39e7-4c7b-9ded-f605e398d94a" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e05da31e-39e7-4c7b-9ded-f605e398d94a")) {                    Plotly.newPlot(                        "e05da31e-39e7-4c7b-9ded-f605e398d94a",                        [{"hovertemplate":"Country=Afghanistan<br>Year=%{x}<br>mean=%{y}<extra></extra>","legendgroup":"Afghanistan","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Afghanistan","showlegend":true,"x":[1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016],"xaxis":"x","y":[12.894487500000004,12.5445475,12.977138333333334,13.08001833333333,13.040894999999999,12.7502675,12.867904999999999,13.4399325,14.073920833333332,13.773886666666668,14.008403333333336,13.815448333333334,13.313425,14.154190833333333,13.38219166666667,14.167483333333335,13.511140833333334,13.752816666666666,13.782173333333333,14.105874166666664,13.728161666666665,12.976280833333334,14.016803333333334,13.647966666666669,13.866921666666668,14.513565],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country=Albania<br>Year=%{x}<br>mean=%{y}<extra></extra>","legendgroup":"Albania","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Albania","showlegend":true,"x":[1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016],"xaxis":"x","y":[11.037649166666668,11.5638675,11.595673333333332,12.52679,11.34531,11.160539166666666,11.411140833333334,11.9686575,12.2526625,12.519675000000001,12.25617916666667,12.335653333333333,12.138400833333334,11.884030833333334,11.405860833333334,11.772879166666668,12.474265,12.600576666666667,12.435141666666668,12.390449166666665,12.169143333333333,12.663002500000003,12.74811333333333,12.70404,12.685259166666667,12.7223375],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country=Algeria<br>Year=%{x}<br>mean=%{y}<extra></extra>","legendgroup":"Algeria","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Algeria","showlegend":true,"x":[1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016],"xaxis":"x","y":[22.513458333333332,22.441875,22.825708333333335,23.251625000000004,23.3613,23.100624999999997,23.492216666666668,23.348291666666668,23.473575,23.396816666666666,23.78484166666667,23.485733333333332,23.709016666666667,23.3809,23.413233333333327,23.670150000000003,23.439533333333333,23.282325000000004,23.763258333333336,24.08575833333333,23.645283333333335,23.631541666666664,23.33160833333333,23.87725,23.656874999999996,24.067066666666665],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country=Andorra<br>Year=%{x}<br>mean=%{y}<extra></extra>","legendgroup":"Andorra","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Andorra","showlegend":true,"x":[1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016],"xaxis":"x","y":[11.188148333333332,11.225924166666667,11.0523775,12.263018333333335,12.021567500000002,11.422869166666665,12.550163333333332,11.730380833333335,11.9696975,12.186415833333333,11.902153333333333,12.104243333333335,12.414215833333335,11.792601666666664,11.411371666666666,12.447480833333335,11.851174166666667,11.741286666666667,12.268426666666668,11.141371666666666,12.653303333333334,12.028117500000002,11.583379166666667,12.831938333333332,12.573666666666666,12.442112499999999],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Count ...

# %% [markdown]
# ### `agg`
#
# `agg` permite agregar datos por grupo usando una o más operaciones:

# %%
prom_t_año_global = temperaturas.groupby(["Year"]).agg(
    {
        "Temperature": ["mean", "std", "min"]
    }
)
prom_t_año_global
# Out:
#      Temperature
#             mean        std     min
# Year
# 1991   18.716174  10.292725 -26.940
# 1992   18.651461  10.173134 -29.905
# 1993   18.632208  10.336513 -30.859
# 1994   18.944268  10.161263 -30.140
# 1995   18.937594  10.209406 -30.282
# 1996   18.630084  10.496066 -27.103
# 1997   18.922807  10.228958 -28.020
# 1998   19.273504  10.353435 -28.307
# 1999   19.085536  10.057636 -27.324
# 2000   19.083361  10.013080 -28.287
# 2001   19.177183  10.245669 -29.376
# 2002   19.296718  10.131432 -29.664
# 2003   19.208448  10.359996 -28.081
# 2004   19.167283  10.150215 -28.010
# 2005   19.185109  10.356420 -25.095
# 2006   19.228243  10.247942 -29.643
# 2007   19.311888   9.994144 -27.231
# 2008   19.172404  10.048448 -29.022
# 2009   19.327523  10.205430 -29.551
# 2010   19.365938  10.526774 -27.970
# 2011   19.184153  10.207967 -26.722
# 2012   19.197032  10.445062 -27.044
# 2013   19.259569  10.190078 -27.253
# 2014   19.464966   9.928222 -28.582
# 2015   19.581111  10.024540 -27.868
# 2016   19.642927  10.119874 -24.596

# %%
px.line(prom_t_año_global.droplevel(0, axis=1).reset_index(), x="Year", y="mean")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="315aee08-644a-4a30-9b33-6e9cb2003ef0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("315aee08-644a-4a30-9b33-6e9cb2003ef0")) {                    Plotly.newPlot(                        "315aee08-644a-4a30-9b33-6e9cb2003ef0",                        [{"hovertemplate":"Year=%{x}<br>mean=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016],"xaxis":"x","y":[18.716173932291667,18.651461445312503,18.6322077734375,18.944267625868054,18.93759394097222,18.630084440104167,18.922806627604167,19.273503849826387,19.08553566840278,19.083360733506947,19.177183389756944,19.29671802083333,19.208448389756946,19.167282951388888,19.185108953993055,19.228242565104168,19.31188802951389,19.172403541666668,19.327522747395832,19.365937526041666,19.18415263888889,19.19703200520833,19.25956903645833,19.464965607638888,19.581110533854165,19.642927235243054],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.33333333333 ...
